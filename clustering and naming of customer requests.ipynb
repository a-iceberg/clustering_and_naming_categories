# %% [markdown]
# # Кластеризация и характеристика обращений клиентов

# %%
import os
import re
import json
import warnings
import logging

import pandas as pd
import numpy as np
import plotly.express as px
import pymssql
import transformers
import torch
import tiktoken

from tqdm.auto import tqdm
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from torch.utils.data import DataLoader
from transformers import AutoTokenizer, AutoModel
from openai import OpenAI
from bert_score import score

warnings.filterwarnings("ignore", category=UserWarning)
pd.set_option('display.max_colwidth', None)
transformers.tokenization_utils.logger.setLevel(logging.ERROR)
transformers.configuration_utils.logger.setLevel(logging.ERROR)
transformers.modeling_utils.logger.setLevel(logging.ERROR)

SEED = 654321

# %%
def ms_sql_con():
    sql_name = 'voice_ai'
    sql_server = '10.2.4.124'
    sql_login = 'ICECORP\\1c_sql'

    with open('sql.pass','r') as file:
        sql_pass = file.read().replace('\n', '')
        file.close()

    return pymssql.connect(
            server = sql_server,
            user = sql_login,
            password = sql_pass,
            database = sql_name,
            tds_version=r'7.0',
            charset='cp1251'
    )

# %%
def read_sql(query):
    return pd.read_sql_query(query, con=ms_sql_con(), parse_dates=None)

# %%
calls_query = '''
SELECT TOP 5 *
FROM calls
WHERE CAST(call_date AS DATE) BETWEEN '2024-02-12' AND '2024-02-12';
'''

# %%
calls_query = '''
SELECT TOP 50 *
FROM queue
ORDER BY record_date;
'''

# %%
calls = read_sql(calls_query)
calls
# Out:
#                   date  cpu_id                  filepath date_y date_m date_d  \
# 0  2024-02-27 12:03:25       0  audio/stereo/2024-02/26/   None   None   None
# 1  2024-02-27 12:03:25       1  audio/stereo/2024-02/26/   None   None   None
# 2  2024-02-27 12:03:38       0               audio/mono/   None   None   None
# 3  2024-02-27 12:03:25       2  audio/stereo/2024-02/26/   None   None   None
# 4  2024-02-27 12:03:25       3  audio/stereo/2024-02/26/   None   None   None
# 5  2024-02-27 12:03:25       4  audio/stereo/2024-02/26/   None   None   None
# 6  2024-02-27 12:03:38       1               audio/mono/   None   None   None
# 7  2024-02-27 12:03:25       5  audio/stereo/2024-02/26/   None   None   None
# 8  2024-02-27 12:03:25       6  audio/stereo/2024-02/27/   None   None   None
# 9  2024-02-27 12:03:25       7  audio/stereo/2024-02/27/   None   None   None
# 10 2024-02-27 12:03:25       8  audio/stereo/2024-02/27/   None   None   None
# 11 2024-02-27 12:03:25       9  audio/stereo/2024-02/27/   None   None   None
# 12 2024-02-27 12:03:25      10  audio/stereo/2024-02/27/   None   None   None
# 13 2024-02-27 12:03:25       0  audio/stereo/2024-02/27/   None   None   None
# 14 2024-02-27 12:03:38       2               audio/mono/   None   None   None
# 15 2024-02-27 12:03:38       3               audio/mono/   None   None   None
# 16 2024-02-27 12:03:25       1  audio/stereo/2024-02/27/   None   None   None
# 17 2024-02-27 12:03:25       2  audio/stereo/2024-02/27/   None   None   None
# 18 2024-02-27 12:03:25       3  audio/stereo/2024-02/27/   None   None   None
# 19 2024-02-27 12:03:38       4               audio/mono/   None   None   None
# 20 2024-02-27 12:03:25       4  audio/stereo/2024-02/27/   None   None   None
# 21 2024-02-27 12:03:25       5  audio/stereo/2024-02/27/   None   None   None
# 22 2024-02-27 12:03:25       6  audio/stereo/2024-02/27/   None   None   None
# 23 2024-02-27 12:03:25       7  audio/stereo/2024-02/27/   None   None   None
# 24 2024-02-27 12:03:38       5               audio/mono/   None   None   None
# 25 2024-02-27 12:03:25       8  audio/stereo/2024-02/27/   None   None   None
# 26 2024-02-27 12:03:38       6               audio/mono/   None   None   None
# 27 2024-02-27 12:03:25       9  audio/stereo/2024-02/27/   None   None   None
# 28 2024-02-27 12:03:25      10  audio/stereo/2024-02/27/   None   None   None
# 29 2024-02-27 12:03:25       0  audio/stereo/2024-02/27/   None   None   None
# 30 2024-02-27 12:03:25       1  audio/stereo/2024-02/27/   None   None   None
# 31 2024-02-27 12:03:25       2  audio/stereo/2024-02/27/   None   None   None
# 32 2024-02-27 12:03:25       3  audio/stereo/2024-02/27/   None   None   None
# 33 2024-02-27 12:03:25       4  audio/stereo/2024-02/27/   None   None   None
# 34 2024-02-27 12:03:25       5  audio/stereo/2024-02/27/   None   None   None
# 35 2024-02-27 12:03:25       6  audio/stereo/2024-02/27/   None   None   None
# 36 2024-02-27 12:03:25       7  audio/stereo/2024-02/27/   None   None   None
# 37 2024-02-27 12:03:25       8  audio/stereo/2024-02/27/   None   None   None
# 38 2024-02-27 12:03:25       9  audio/stereo/2024-02/27/   None   None   None
# 39 2024-02-27 12:03:25      10  audio/stereo/2024-02/27/   None   None   None
# 40 2024-02-27 12:03:38       7               audio/mono/   None   None   None
# 41 2024-02-27 12:03:25       0  audio/stereo/2024-02/27/   None   None   None
# 42 2024-02-27 12:03:25       1  audio/stereo/2024-02/27/   None   None   None
# 43 2024-02-27 12:03:25       2  audio/stereo/2024-02/27/   None   None   None
# 44 2024-02-27 12:03:25       3  audio/stereo/2024-02/27/   None   None   None
# 45 2024-02-27 12:03:25       4  audio/stereo/2024-02/27/   None   None   None
# 46 2024-02-27 12:03:25       5  audio/stereo/2024-02/27/   None   None   None
# 47 2024-02-27 12:03:25       6  audio/stereo/2024-02/27/   None   None   None
# 48 2024-02-27 12:03:25       7  audio/stereo/2024-02/27/   None   None   None
# 49 2024-02-27 12:03:25       8  audio/stereo/2024-02/27/   None   None   None
#
#                                                                           filename  \
# 0                                          in_5069_2024-02-26-09-28-09rxtx-out.wav
# 1                                    in_79032730615_2024-02-26-10-39-07rxtx-in.wav
# 2    a2024-02-26t11:34:50b_c9035448348d_e9262855670f_g1708936490.25048526h-out.wav
# 3                                    in_9851187036_2024-02-26-11-37-21rxtx-out.wav
# 4                                    in_79258659525_2024-02-26-13-46-50rxtx-in.wav
# 5                                    in_79267075427_2024-02-26-14-22-46rxtx-in.wav
# 6     a2024-02-26t14:53:15b_c9260096272d_e9636110411f_g1708948395.25059207h-in.wav
# 7                                     in_9811487284_2024-02-26-15-01-49rxtx-in.wav
# 8                                          in_1588_2024-02-27-09-24-53rxtx-out.wav
# 9                                    in_79150417763_2024-02-27-09-25-14rxtx-in.wav
# 10                                  in_79150417763_2024-02-27-09-25-14rxtx-out.wav
# 11                                   in_9060721520_2024-02-27-09-26-18rxtx-out.wav
# 12                                  in_79105020692_2024-02-27-09-26-33rxtx-out.wav
# 13                                  in_79163393659_2024-02-27-09-26-52rxtx-out.wav
# 14   a2024-02-27t09:26:53b_c79200159224d_e9601720170f_g1709015208.25075409h-in.wav
# 15  a2024-02-27t09:26:53b_c79200159224d_e9601720170f_g1709015208.25075409h-out.wav
# 16                                          in_5113_2024-02-27-09-27-09rxtx-in.wav
# 17                                  in_79651072211_2024-02-27-09-27-15rxtx-out.wav
# 18                                   in_79101468567_2024-02-27-09-27-45rxtx-in.wav
# 19    a2024-02-27t09:27:53b_c9062896510d_e9112246304f_g1709015273.25075472h-in.wav
# 20                                  in_79772669042_2024-02-27-09-28-22rxtx-out.wav
# 21                                         in_5011_2024-02-27-09-28-41rxtx-out.wav
# 22                                    in_3832625966_2024-02-27-09-29-26rxtx-in.wav
# 23                                  in_79261045905_2024-02-27-09-30-23rxtx-out.wav
# 24    a2024-02-27t09:31:05b_c9130000335d_e9137169129f_g1709015464.25075646h-in.wav
# 25                                   in_9850065030_2024-02-27-09-32-34rxtx-out.wav
# 26   a2024-02-27t09:36:51b_c9260225681d_e9260414751f_g1709015811.25075898h-out.wav
# 27                                  in_79067565295_2024-02-27-09-37-07rxtx-out.wav
# 28                                   in_79160874324_2024-02-27-09-37-36rxtx-in.wav
# 29                                          in_5015_2024-02-27-09-38-13rxtx-in.wav
# 30                                   in_79164614634_2024-02-27-09-40-38rxtx-in.wav
# 31                                  in_79164614634_2024-02-27-09-40-38rxtx-out.wav
# 32                                   in_79161887661_2024-02-27-09-40-55rxtx-in.wav
# 33                                   in_9104733712_2024-02-27-09-43-28rxtx-out.wav
# 34                                    in_9062541679_2024-02-27-09-44-26rxtx-in.wav
# 35                                   in_9062541679_2024-02-27-09-44-26rxtx-out.wav
# 36                                   in_79037402945_2024-02-27-09-46-38rxtx-in.wav
# 37                                  in_79037402945_2024-02-27-09-46-38rxtx-out.wav
# 38                                   in_79163125959_2024-02-27-09-47-44rxtx-in.wav
# 39                                  in_79163125959_2024-02-27-09-47-44rxtx-out.wav
# 40    a2024-02-27t09:47:51b_c9155806367d_e9611870020f_g1709016471.25076216h-in.wav
# 41                                    in_9264327901_2024-02-27-09-48-28rxtx-in.wav
# 42                                   in_9264327901_2024-02-27-09-48-28rxtx-out.wav
# 43                                  in_79852825838_2024-02-27-09-48-39rxtx-out.wav
# 44                                          in_5164_2024-02-27-09-49-11rxtx-in.wav
# 45                                    in_9111259792_2024-02-27-09-49-16rxtx-in.wav
# 46                                   in_9111259792_2024-02-27-09-49-16rxtx-out.wav
# 47                                         in_5106_2024-02-27-09-49-31rxtx-out.wav
# 48                                   in_74955272542_2024-02-27-09-50-07rxtx-in.wav
# 49                                  in_74955272542_2024-02-27-09-50-07rxtx-out.wav
#
#     duration         record_date  source_id          src         dst  \
# 0    29.9800 2024-02-26 09:28:09          1         5069        5102
# 1   172.1800 2024-02-26 10:39:07          1  79032730615        5076
# 2   139.2600 2024-02-26 11:34:50          2   9035448348  9262855670
# 3   236.1800 2024-02-26 11:37:21          1   9851187036        5051
# 4   289.0000 2024-02-26 13:46:50          1  79258659525        5069
# 5   123.4400 2024-02-26 14:22:46          1  79267075427        5069
# 6    68.1800 2024-02-26 14:53:15          2   9260096272  9636110411
# 7     0.7400 2024-02-26 15:01:49          1   9811487284        None
# 8   287.3600 2024-02-27 09:24:53          1         1588        main
# 9   476.4200 2024-02-27 09:25:14          1  79150417763        5062
# 10  476.2200 2024-02-27 09:25:14          1  79150417763        5062
# 11   71.0400 2024-02-27 09:26:18          1   9060721520        5116
# 12  373.9800 2024-02-27 09:26:33          1  79105020692        5069
# 13   41.2600 2024-02-27 09:26:52          1  79163393659        5011
# 14  356.2400 2024-02-27 09:26:53          2  79200159224  9601720170
# 15  356.3800 2024-02-27 09:26:53          2  79200159224  9601720170
# 16  159.1000 2024-02-27 09:27:09          1         5113        main
# 17  193.1800 2024-02-27 09:27:15          1  79651072211        5021
# 18  276.1400 2024-02-27 09:27:45          1  79101468567        5108
# 19  127.7600 2024-02-27 09:27:53          2   9062896510  9112246304
# 20  349.2600 2024-02-27 09:28:22          1  79772669042        5036
# 21  170.5000 2024-02-27 09:28:41          1         5011        main
# 22   42.7600 2024-02-27 09:29:26          1   3832625966        5033
# 23  207.1800 2024-02-27 09:30:23          1  79261045905        5048
# 24   78.2400 2024-02-27 09:31:05          2   9130000335  9137169129
# 25  496.9200 2024-02-27 09:32:34          1   9850065030        5125
# 26  322.0400 2024-02-27 09:36:51          2   9260225681  9260414751
# 27  281.1200 2024-02-27 09:37:07          1  79067565295        5031
# 28  249.2000 2024-02-27 09:37:36          1  79160874324        5036
# 29   89.1455 2024-02-27 09:38:13          1         5015        main
# 30  471.8600 2024-02-27 09:40:38          1  79164614634        5113
# 31  471.8400 2024-02-27 09:40:38          1  79164614634        5113
# 32   37.6600 2024-02-27 09:40:55          1  79161887661        5011
# 33  272.8400 2024-02-27 09:43:28          1   9104733712        5054
# 34  262.2200 2024-02-27 09:44:26          1   9062541679        5062
# 35  262.5800 2024-02-27 09:44:26          1   9062541679        5062
# 36  235.4600 2024-02-27 09:46:38          1  79037402945        5054
# 37  235.7400 2024-02-27 09:46:38          1  79037402945        5054
# 38  305.5200 2024-02-27 09:47:44          1  79163125959        5056
# 39  305.7000 2024-02-27 09:47:44          1  79163125959        5056
# 40   96.0000 2024-02-27 09:47:51          2   9155806367  9611870020
# 41  301.2000 2024-02-27 09:48:28          1   9264327901        5067
# 42  301.1800 2024-02-27 09:48:28          1   9264327901        5067
# 43  132.5400 2024-02-27 09:48:39          1  79852825838        5089
# 44   15.6000 2024-02-27 09:49:11          1         5164        main
# 45  110.5000 2024-02-27 09:49:16          1   9111259792        5058
# 46  110.4600 2024-02-27 09:49:16          1   9111259792        5058
# 47   88.3800 2024-02-27 09:49:31          1         5106        main
# 48  137.8000 2024-02-27 09:50:07          1  74955272542        5069
# 49  137.8200 2024-02-27 09:50:07          1  74955272542        5069
#
#                linkedid  version  file_size
# 0   1708928888.17083750        0     479724
# 1   1708933146.17087562        0    2754924
# 2   1708936490.25048526        1    2228204
# 3   1708936640.17090924        0    3778924
# 4   1708944409.17098161        0    4624044
# 5   1708946565.17100249        0    1975084
# 6   1708948395.25059207        1    1090924
# 7   1708948908.17102771        0      11884
# 8   1709015028.17123171        0    4597804
# 9   1709015113.17123212        0    7622764
# 10  1709015113.17123212        0    7619564
# 11  1709015177.17123269        0    1136684
# 12  1709015191.17123286        0    5983724
# 13  1709015210.17123313        0     660204
# 14  1709015208.25075409        1    5699884
# 15  1709015208.25075409        1    5702124
# 16  1709015226.17123328        0    2545644
# 17  1709015234.17123334        0    3090924
# 18  1709015264.17123359        0    4418284
# 19  1709015273.25075472        1    2044204
# 20  1709015300.17123374        0    5588204
# 21  1709015321.17123398        0    2728044
# 22  1709015365.17123436        0     684204
# 23  1709015422.17123460        0    3314924
# 24  1709015464.25075646        1    1251884
# 25  1709015553.17123553        0    7950764
# 26  1709015811.25075898        1    5152684
# 27  1709015826.17123819        0    4497964
# 28  1709015855.17123836        0    3987244
# 29  1709015662.17123680        0    1426372
# 30  1709016037.17123965        0    7549804
# 31  1709016037.17123965        0    7549484
# 32  1709016054.17123983        0     602604
# 33  1709016207.17124136        0    4365484
# 34  1709016265.17124205        0    4195564
# 35  1709016265.17124205        0    4201324
# 36  1709016397.17124312        0    3767404
# 37  1709016397.17124312        0    3771884
# 38  1709016462.17124366        0    4888364
# 39  1709016462.17124366        0    4891244
# 40  1709016471.25076216        1    1536044
# 41  1709016507.17124391        0    4819244
# 42  1709016507.17124391        0    4818924
# 43  1709016517.17124410        0    2120684
# 44  1709016551.17124459        0     249644
# 45  1709016555.17124462        0    1768044
# 46  1709016555.17124462        0    1767404
# 47  1709016571.17124467        0    1414124
# 48  1709016606.17124492        0    2204844
# 49  1709016606.17124492        0    2205164

# %%
tr_query = '''
SELECT TOP 5 *
FROM transcribations
WHERE CAST(record_date AS DATE) BETWEEN '2024-02-12' AND '2024-02-12';
'''

# %%
transcribations = read_sql(tr_query)
transcribations.T
# Out:
#                                                            0  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                                     ага
# start                                                   5.04
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                0.658982
# end_time                                                7.62
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562822
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                            1  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                                    ноля
# start                                                  13.35
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                0.703238
# end_time                                               13.98
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562823
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                                                       2  \
# transcribation_date                                                 2024-02-12 04:14:00
# date_y                                                                             None
# date_m                                                                             None
# date_d                                                                             None
# side                                                                               True
# text                 ну просто там семи часов поэтому я позвонил там было сказано семьи
# start                                                                             20.88
# audio_file_name                                 in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                                           0.980824
# end_time                                                                          26.85
# sentiment                                                                          None
# sentiment_pos                                                                      None
# sentiment_neg                                                                      None
# ID                                                                            172562824
# linkedid                                                            1707699340.16619238
# dst                                                                                main
# record_date                                                         2024-02-12 03:55:42
# source_id                                                                             1
# src                                                                                5015
# cpu_id                                                                                2
# duration                                                                         370.82
# file_size                                                                       5933164
# queue_date                                                          2024-02-12 04:11:53
# model                                                                                 0
#
#                                                              3  \
# transcribation_date                        2024-02-12 04:14:00
# date_y                                                    None
# date_m                                                    None
# date_d                                                    None
# side                                                      True
# text                 а мне бы вот вы знаете у меня холодильник
# start                                                    29.97
# audio_file_name        in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                       1.0
# end_time                                                 32.55
# sentiment                                                 None
# sentiment_pos                                             None
# sentiment_neg                                             None
# ID                                                   172562825
# linkedid                                   1707699340.16619238
# dst                                                       main
# record_date                                2024-02-12 03:55:42
# source_id                                                    1
# src                                                       5015
# cpu_id                                                       2
# duration                                                370.82
# file_size                                              5933164
# queue_date                                 2024-02-12 04:11:53
# model                                                        0
#
#                                                                                                                                                           4  \
# transcribation_date                                                                                                                     2024-02-12 04:14:00
# date_y                                                                                                                                                 None
# date_m                                                                                                                                                 None
# date_d                                                                                                                                                 None
# side                                                                                                                                                   True
# text                 такой большой но он давно уже стоит бош называется вот холодильная камера внизу вроде морозит а сам холодильник тёпленький не работает
# start                                                                                                                                                 33.15
# audio_file_name                                                                                                     in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                                                                                                               0.972066
# end_time                                                                                                                                              44.13
# sentiment                                                                                                                                              None
# sentiment_pos                                                                                                                                          None
# sentiment_neg                                                                                                                                          None
# ID                                                                                                                                                172562826
# linkedid                                                                                                                                1707699340.16619238
# dst                                                                                                                                                    main
# record_date                                                                                                                             2024-02-12 03:55:42
# source_id                                                                                                                                                 1
# src                                                                                                                                                    5015
# cpu_id                                                                                                                                                    2
# duration                                                                                                                                             370.82
# file_size                                                                                                                                           5933164
# queue_date                                                                                                                              2024-02-12 04:11:53
# model                                                                                                                                                     0
#
#                                                            5  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                         яков меня зовут
# start                                                  46.23
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                     1.0
# end_time                                               47.34
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562827
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                            6  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                                      да
# start                                                   51.9
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                     1.0
# end_time                                               52.23
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562828
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                            7  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                                  хорошо
# start                                                  66.63
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                     1.0
# end_time                                               67.23
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562829
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                            8  \
# transcribation_date                      2024-02-12 04:14:00
# date_y                                                  None
# date_m                                                  None
# date_d                                                  None
# side                                                    True
# text                                            нет наоборот
# start                                                  74.58
# audio_file_name      in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                     1.0
# end_time                                               75.87
# sentiment                                               None
# sentiment_pos                                           None
# sentiment_neg                                           None
# ID                                                 172562830
# linkedid                                 1707699340.16619238
# dst                                                     main
# record_date                              2024-02-12 03:55:42
# source_id                                                  1
# src                                                     5015
# cpu_id                                                     2
# duration                                              370.82
# file_size                                            5933164
# queue_date                               2024-02-12 04:11:53
# model                                                      0
#
#                                                                                         9
# transcribation_date                                                   2024-02-12 04:14:00
# date_y                                                                               None
# date_m                                                                               None
# date_d                                                                               None
# side                                                                                 True
# text                 в холодильной холодильнике нет не работает а морозилка вроде морозит
# start                                                                               76.95
# audio_file_name                                   in_5015_2024-02-12-03-55-42rxtx-out.wav
# conf                                                                             0.937414
# end_time                                                                            82.17
# sentiment                                                                            None
# sentiment_pos                                                                        None
# sentiment_neg                                                                        None
# ID                                                                              172562831
# linkedid                                                              1707699340.16619238
# dst                                                                                  main
# record_date                                                           2024-02-12 03:55:42
# source_id                                                                               1
# src                                                                                  5015
# cpu_id                                                                                  2
# duration                                                                           370.82
# file_size                                                                         5933164
# queue_date                                                            2024-02-12 04:11:53
# model                                                                                   0

# %%
query = '''
SELECT DISTINCT
       start,
       record_date,
       linkedid,
       audio_file_name,
       model,
       text,
       side,
       src,
       dst
FROM transcribations
WHERE linkedid IN (SELECT DISTINCT
                          linkedid
                   FROM transcribations
                   WHERE CAST(record_date AS DATE) BETWEEN '2024-02-07' AND '2024-02-15'
                       AND model=1)
    AND ((side='True' AND LEN(src)=4 AND dst NOT LIKE '[0-9][0-9][0-9][0-9]')
         OR (side='False' AND LEN(src)>4 AND dst LIKE '[0-9][0-9][0-9][0-9]')
         OR (side='True' AND LEN(src)>4 AND LEN(dst)>4))
    AND text IS NOT NULL AND text <> ''
ORDER BY start;
'''

# %%
query = '''
SELECT DISTINCT
       start,
       record_date,
       linkedid,
       audio_file_name,
       model,
       text,
       side,
       src,
       dst
FROM transcribations
WHERE CAST(record_date AS DATE) BETWEEN '2024-02-07' AND '2024-02-13'
    AND text IS NOT NULL AND text <> ''
    AND linkedid IS NOT NULL AND linkedid <> ''
ORDER BY start;
'''

# %%
df = read_sql(query)
df = df.drop(columns=['start']).drop_duplicates()
df.head()
# Out:
#           record_date             linkedid  \
# 0 2024-02-07 08:22:09  1707283327.16459181
# 1 2024-02-07 08:26:56  1707283614.16459261
# 2 2024-02-07 08:29:08  1707283748.16459303
# 3 2024-02-07 08:53:22  1707285201.24553903
# 4 2024-02-07 09:08:45  1707286125.16460275
#
#                                                                    audio_file_name  \
# 0                                           in_5056_2024-02-07-08-22-09rxtx-in.wav
# 1                                           in_5109_2024-02-07-08-26-56rxtx-in.wav
# 2                                           in_5021_2024-02-07-08-29-08rxtx-in.wav
# 3  a2024-02-07t08:53:22b_c9255710403d_e0029859534316f_g1707285201.24553903h-in.wav
# 4                                           in_5011_2024-02-07-09-08-45rxtx-in.wav
#
#    model                           text   side         src            dst
# 0      1         Продолжение следует...  False        5056           main
# 1      1   Субтитры создавал DimaTorzok  False        5109           main
# 2      0                    доброе утро  False        5021           main
# 3      0                      что ладно  False  9255710403  0029859534316
# 4      1         Продолжение следует...  False        5011           main

# %%
# df.to_csv('calls_transcripts.csv', index=False)
# df = pd.read_csv(
#     'calls_transcripts.csv',
#     parse_dates=[0],
#     dtype={'linkedid': 'object'}
# )

# %%
summarized = df.groupby(
    [
       'linkedid',
       'audio_file_name',
       'record_date',
       'model',
       'side',
       'src',
       'dst'
    ],
    as_index=False
).agg({'text': ' '.join})

# %%
summarized['text'] = summarized['text'].str.lower().replace(
    'продолжение следует',
    '',
    regex=True
)
summarized['text'] = summarized['text'].str.lower().replace(
    r'\.{2,}',
    '',
    regex=True
)

# %%
# summarized['text_length'] = summarized['text'].apply(len)
# summarized = summarized[summarized['text_length'] >= 50]
summarized = summarized.sort_values(by=['linkedid', 'record_date'])#.drop_duplicates(subset='linkedid').reset_index(drop=True)

# %%
summarized.linkedid.nunique(), summarized.shape
# Out:
# (43933, (90691, 8))

# %%
# Определяем дубликаты linkedid с учетом различия record_date
summarized['is_duplicate'] = summarized.duplicated(subset=['linkedid', 'record_date'], keep='first')

# Группируем по linkedid и фильтруем только те группы, где есть разные record_date
# Для каждой группы проверяем, что количество уникальных record_date больше 1
grouped = summarized.groupby('linkedid').filter(lambda x: x['record_date'].nunique() > 1)

# Из полученных групп исключаем строки, помеченные как дубликаты
filtered = grouped[grouped['is_duplicate']]

# Удаляем вспомогательные столбцы
filtered = filtered.drop(columns=['is_duplicate'])

# %%
filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8136 entries, 360 to 90549
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   linkedid         8136 non-null   object
#  1   audio_file_name  8136 non-null   object
#  2   record_date      8136 non-null   datetime64[ns]
#  3   model            8136 non-null   int64
#  4   side             8136 non-null   bool
#  5   src              8136 non-null   object
#  6   dst              8136 non-null   object
#  7   text             8136 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(5)
# memory usage: 516.4+ KB

# %%
grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16379 entries, 359 to 90549
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   linkedid         16379 non-null  object
#  1   audio_file_name  16379 non-null  object
#  2   record_date      16379 non-null  datetime64[ns]
#  3   model            16379 non-null  int64
#  4   side             16379 non-null  bool
#  5   src              16379 non-null  object
#  6   dst              16379 non-null  object
#  7   text             16379 non-null  object
#  8   is_duplicate     16379 non-null  bool
# dtypes: bool(2), datetime64[ns](1), int64(1), object(5)
# memory usage: 1.0+ MB

# %%
grouped.sort_values(by='linkedid').head(50)
# Out:
#                 linkedid                                 audio_file_name  \
# 359  1707282963.16459094   in_79636990202_2024-02-07-08-16-05rxtx-in.wav
# 360  1707282963.16459094  in_79636990202_2024-02-07-08-16-05rxtx-out.wav
# 356  1707282963.16459094          in_5108_2024-02-07-08-17-58rxtx-in.wav
# 357  1707282963.16459094          in_5108_2024-02-07-08-18-44rxtx-in.wav
# 358  1707282963.16459094         in_5108_2024-02-07-08-18-44rxtx-out.wav
# 442  1707283737.16459296    in_9031680317_2024-02-07-08-28-58rxtx-in.wav
# 443  1707283737.16459296   in_9031680317_2024-02-07-08-28-58rxtx-out.wav
# 440  1707283737.16459296          in_5109_2024-02-07-08-30-07rxtx-in.wav
# 441  1707283737.16459296         in_5109_2024-02-07-08-30-07rxtx-out.wav
# 520  1707284834.16459473   in_79518248712_2024-02-07-08-47-15rxtx-in.wav
# 521  1707284834.16459473  in_79518248712_2024-02-07-08-47-15rxtx-out.wav
# 518  1707284834.16459473          in_5015_2024-02-07-08-52-29rxtx-in.wav
# 519  1707284834.16459473         in_5015_2024-02-07-08-52-29rxtx-out.wav
# 527  1707284906.16459515         in_5113_2024-02-07-08-52-44rxtx-out.wav
# 526  1707284906.16459515          in_5113_2024-02-07-08-52-44rxtx-in.wav
# 525  1707284906.16459515         in_5113_2024-02-07-08-50-37rxtx-out.wav
# 529  1707284906.16459515  in_79265726876_2024-02-07-08-48-27rxtx-out.wav
# 528  1707284906.16459515   in_79265726876_2024-02-07-08-48-27rxtx-in.wav
# 524  1707284906.16459515          in_5113_2024-02-07-08-50-37rxtx-in.wav
# 546  1707285051.16459541    in_9944286982_2024-02-07-08-50-52rxtx-in.wav
# 547  1707285051.16459541   in_9944286982_2024-02-07-08-50-52rxtx-out.wav
# 544  1707285051.16459541          in_5108_2024-02-07-08-52-25rxtx-in.wav
# 545  1707285051.16459541         in_5108_2024-02-07-08-52-25rxtx-out.wav
# 558  1707285099.16459564         in_5108_2024-02-07-08-51-40rxtx-out.wav
# 557  1707285099.16459564          in_5108_2024-02-07-08-51-40rxtx-in.wav
# 559  1707285099.16459564          in_5108_2024-02-07-08-53-17rxtx-in.wav
# 560  1707285099.16459564          in_5108_2024-02-07-08-53-37rxtx-in.wav
# 573  1707285168.16459593   in_79616373926_2024-02-07-08-52-49rxtx-in.wav
# 574  1707285168.16459593  in_79616373926_2024-02-07-08-52-49rxtx-out.wav
# 571  1707285168.16459593          in_5109_2024-02-07-08-54-42rxtx-in.wav
# 572  1707285168.16459593         in_5109_2024-02-07-08-54-42rxtx-out.wav
# 582  1707285242.16459641         in_5056_2024-02-07-08-57-02rxtx-out.wav
# 581  1707285242.16459641          in_5056_2024-02-07-08-57-02rxtx-in.wav
# 584  1707285242.16459641  in_79166746988_2024-02-07-08-54-03rxtx-out.wav
# 583  1707285242.16459641   in_79166746988_2024-02-07-08-54-03rxtx-in.wav
# 591  1707285260.16459647    in_9119233356_2024-02-07-08-54-21rxtx-in.wav
# 592  1707285260.16459647   in_9119233356_2024-02-07-08-54-21rxtx-out.wav
# 589  1707285260.16459647          in_5113_2024-02-07-08-55-53rxtx-in.wav
# 590  1707285260.16459647         in_5113_2024-02-07-08-55-53rxtx-out.wav
# 596  1707285266.16459655         in_5125_2024-02-07-08-58-25rxtx-out.wav
# 595  1707285266.16459655          in_5125_2024-02-07-08-58-25rxtx-in.wav
# 594  1707285266.16459655         in_5125_2024-02-07-08-55-50rxtx-out.wav
# 598  1707285266.16459655   in_9992383228_2024-02-07-08-54-27rxtx-out.wav
# 597  1707285266.16459655    in_9992383228_2024-02-07-08-54-27rxtx-in.wav
# 593  1707285266.16459655          in_5125_2024-02-07-08-55-50rxtx-in.wav
# 601  1707285286.16459662    in_9944286982_2024-02-07-08-54-47rxtx-in.wav
# 602  1707285286.16459662   in_9944286982_2024-02-07-08-54-47rxtx-out.wav
# 599  1707285286.16459662          in_5108_2024-02-07-08-56-38rxtx-in.wav
# 600  1707285286.16459662         in_5108_2024-02-07-08-56-38rxtx-out.wav
# 648  1707285598.16459772   in_9260487885_2024-02-07-09-02-08rxtx-out.wav
#
#             record_date  model   side          src   dst  \
# 359 2024-02-07 08:16:05      1  False  79636990202  5011
# 360 2024-02-07 08:16:05      0   True  79636990202  5011
# 356 2024-02-07 08:17:58      0  False         5108  main
# 357 2024-02-07 08:18:44      0  False         5108  main
# 358 2024-02-07 08:18:44      0   True         5108  main
# 442 2024-02-07 08:28:58      0  False   9031680317  5109
# 443 2024-02-07 08:28:58      0   True   9031680317  5109
# 440 2024-02-07 08:30:07      0  False         5109  main
# 441 2024-02-07 08:30:07      0   True         5109  main
# 520 2024-02-07 08:47:15      0  False  79518248712  5015
# 521 2024-02-07 08:47:15      0   True  79518248712  5015
# 518 2024-02-07 08:52:29      0  False         5015  main
# 519 2024-02-07 08:52:29      0   True         5015  main
# 527 2024-02-07 08:52:44      0   True         5113  main
# 526 2024-02-07 08:52:44      0  False         5113  main
# 525 2024-02-07 08:50:37      0   True         5113  main
# 529 2024-02-07 08:48:27      0   True  79265726876  5033
# 528 2024-02-07 08:48:27      0  False  79265726876  5033
# 524 2024-02-07 08:50:37      0  False         5113  main
# 546 2024-02-07 08:50:52      0  False   9944286982  5108
# 547 2024-02-07 08:50:52      0   True   9944286982  5108
# 544 2024-02-07 08:52:25      0  False         5108  main
# 545 2024-02-07 08:52:25      0   True         5108  main
# 558 2024-02-07 08:51:40      0   True         5108  main
# 557 2024-02-07 08:51:40      0  False         5108  main
# 559 2024-02-07 08:53:17      0  False         5108  main
# 560 2024-02-07 08:53:37      0  False         5108  main
# 573 2024-02-07 08:52:49      0  False  79616373926  5109
# 574 2024-02-07 08:52:49      0   True  79616373926  5109
# 571 2024-02-07 08:54:42      0  False         5109  main
# 572 2024-02-07 08:54:42      0   True         5109  main
# 582 2024-02-07 08:57:02      0   True         5056  main
# 581 2024-02-07 08:57:02      0  False         5056  main
# 584 2024-02-07 08:54:03      0   True  79166746988  5056
# 583 2024-02-07 08:54:03      1  False  79166746988  5056
# 591 2024-02-07 08:54:21      0  False   9119233356  5113
# 592 2024-02-07 08:54:21      0   True   9119233356  5113
# 589 2024-02-07 08:55:53      0  False         5113  main
# 590 2024-02-07 08:55:53      0   True         5113  main
# 596 2024-02-07 08:58:25      0   True         5125  main
# 595 2024-02-07 08:58:25      0  False         5125  main
# 594 2024-02-07 08:55:50      0   True         5125  main
# 598 2024-02-07 08:54:27      0   True   9992383228  5125
# 597 2024-02-07 08:54:27      0  False   9992383228  5125
# 593 2024-02-07 08:55:50      0  False         5125  main
# 601 2024-02-07 08:54:47      0  False   9944286982  5108
# 602 2024-02-07 08:54:47      0   True   9944286982  5108
# 599 2024-02-07 08:56:38      0  False         5108  main
# 600 2024-02-07 08:56:38      0   True         5108  main
# 648 2024-02-07 09:02:08      0   True   9260487885  main
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 359                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    здравствуйте, елена. меня наталья зовут.  как раз я у вас несколько дней в воскресенье сделала заказ на мещерский переулок, дом 6, корпус 2.  так, до сих пор мастер не пришел, не звонил.  нет, не звонил, да.  меня связывали с техническим отделом на второй день.  и мне сказали, что он заболел и что сегодня он должен выйти.  вот как бы с техническим отделом выяснить, ждать мне сегодня мастера или нет,  или мне предложили заказать другого мастера.  а вы не могли бы мне связать с ними, потому что меня прям напрямую связывали,  потому что уже то, что говорят, мне позавчера сказали,  что прям вам сейчас  сейчас перезвонят, и никто мне не перезвонил в течение дня.  спасибо, лена, спасибо большое. спасибо.  спасибо.  так.  подскажите, пожалуйста, мне номер заказа мой.  214-7218.  спасибо большое.  в течение какого времени он перезвонит мне?  хорошо, будем надеяться.  просто не хотела бы плохой отзыв оставлять о вашей фирме.  24 часа срочный ремонт.  уже четвертый день, но его как бы нет.  все, спасибо большое.  всего доброго.
# 360                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       здравствуйте сервисный центр оператор елена чем могу помочь вам да угу так а он не звонил не звонил да я восприняла анатолий хороший я сейчас тогда вокруг контроля отправлю сообщение что они позвонили узнали понятно не знаю хорошо да оставайтесь на линии попробую вас видеть добрый день сервисный центр и оставайтесь на линии я попробую уточнить у мастера время визита ментов спасибо большое за ожидание к сожалению мастера занят телефон сейчас не смогла дозвониться я ему тогда отправлю сообщение чтобы он вам перезвонил двести четырнадцать семьдесят два восемнадцать ну пожалуйста но в течение двух часов да пожалуйста все добро
# 356                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         добрый день сервисный центр и оставайтесь на линии я попробую уточнить у мастера время визита ментов
# 357                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                спасибо большое за ожидание обсуждению у мастера занят телефон сейчас не смогла дозвониться ему тогда отправлю сообщение чтобы он вам перезвонил двести четырнадцать семьдесят два восемнадцать ну пожалуйста но в течение двух часов да пожалуйста все добро
# 358                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          как подскажите пожалуйста мне номер заказа мой весть четырнадцать двести четырнадцать семьдесят два восемнадцать спасибо большое в течение какого времени он перезвонит мне хорошо будем надеяться просто не хотелось бы плохой отзыв отзыва это оставили в вашей фирме двадцать четыре часа срочный ремонт уже четвёртый день у него как бы нету все спасибо большое всего доброго
# 442                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              так доброе утро двести четырнадцать семьдесят девять девяносто один да тогда можно будет прослушать что она сказала оператора домой клиент но вот именно по какой причине отказа она не берет телефон потому что вчера получается она только выгрузилась и тут же отказ нет так получается понимаешь а вот я не могу понять такие заявки прослушать их нельзя она получается вчера только выгрузились и через минуту приходит отказ что это заявка такая понятно то есть у вас что прослушивание убрали что ли отказали а им именно именно именно по этой заявке даты и месяц все понял таня спасибо большая да
# 443                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            а такая татьяна доброе так народного ополчения сейчас ой блин а не слушается не давай позвоню уточню неё а не берет он да и сейчас может возьмёт ну да как сброс идёт но чем закрывать семьдесят один и все но можешь анне сергеевне чтоб она сделала запрос вайтишников на прослушку и все вашему ниче тебе ничем не поможем почему оно есть но нет возможности что там или у оператора неправильно кнопку нажал и у нас нет возможности не удалось получить файлы аудиозаписи да да да да да да
# 440                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ну да как сброс идёт но чем закрывать семьдесят один и все но можешь анне сергеевне чтоб она сделала запрос вайтишников на прослушку и все вашему ниче тебе ничем не поможем почему оно есть но нет возможности что там или у оператора неправильно кнопку нажал и у нас нет возможности не удалось получить файлы аудиозаписи да да да да да да
# 441                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            я так получается понимаешь вот я не могу понять такие заявки прослушать их нельзя она получается вчера только выгрузился и через минуту приходит отказ что это заявка такая понятно то есть у вас что прослушивание убрали что ли отказали а им именно именно именно по этой заявке даты и мифы все понял таня спасибо большая да
# 520  а здравствуйте здравствуйте марина знаете вчера к нам приходил телемастер я делал заявку и вот у меня есть наряд заказ тот номер крови какая фамилия мороз или что ли мороз или ногу заявка сто двадцать четыре пятьдесят три шестьдесят но где-то вчера часов в десять так в одиннадцать примерно в это же время те да да да правильно и вот значит он но там нужно было антенны все это сделаю подтвердил он вроде подсоединил показала там ну для проверки то включили все выключили а вечером я включил телевизор он вообще крепить стреляет глючит но вообще не можно смотреть ну что ж этот опять это же мастера вызывать да да каналы он настроил а другой телевизор антенна бетон антенна там намного эти стопера как называется род отсоединил там и вот для проверки отключили показывает ну и выключили а вечером когда включают телевизор посмотреть и все конец вообще реальные цвета стрелять что-то щёлкает экран всяко-разным но мне пока непонятно выключила сейчас звонок как было теорией ну вот вчера был вчера января а то может там другую квартиру может быть такой пожилой мужчина был вот там он проводил полностью из подъезда там его было много а вчера вот был то тоже парень пантерный только в другой квартире профильных вдоль морочили ведь восемь девятьсот пятьдесят один восемьсот двадцать четыре в этом десяти двенадцать двести сорок восемь а ещё был сто восемьдесят третьем там нормально все что что подождать подожди я на телефоне подожди я же вскричал но я чего не так встречал другим другим пультом в туле что что я не понял три тысячи да как-как обсудим мне мопед тоже платить придётся да аматор тоже этот раз другой будет пора хорошо а когда такое время когда ждать да да да да все правильно хорошо хорошо спасибо большое потом напитка все равно не запомню хорошо хорошо до свидания спасибо
# 521                                                                                                                           здравствуйте сервисного центра оператора марина чем могу вам помочь продиктуйте пожалуйста заявку когда мастер был у вас так пятьдесят три шестьдесят так это орбитальная семьдесят четыре правильно какой сейчас вопрос да то есть мастер у вас настраивал каналы или с антенна работал так о посмотрите пятьдесят три шестьдесят этого заявка была в январе месяце в январе месяце мастер был у вас наш в январе не было мастера в конце января так вы имеете другую квартиру тоже орбитальная дом семьдесят четыре да антенну да так сейчас минуту пожалуйста сейчас вернусь сейчас разберёмся телефон его контакты мне продиктуйте пожалуйста дальше минута к орбитальной семьдесят четыре мастер был у вас вчера да так какая в какую квартиру вызывает мастера двести сорок восемь ещё в какой квартире был мастер сто восемьдесят три двести сорок восемь на линии оставайтесь не отвечать сейчас попробуем выяснить минуту да подождите на линии пожалуйста спасибо за ожидание значит на завтра я значит я вам сейчас сделаю повторный вызов сколько вы за ремонт заплатите сколько за ремонт заплатили значит сейчас вам делаю повторный вызов массы с вами созвониться в течение часа с ним уже все обсудите так и поспишь ма нет но я вам сейчас пока делаю повторный вызов по гарантии мастера мастер позвонит вам уже уже с ним обсудите все так что вам что тот же мастер будет конечно тут же в течение часа мастер вам позвонить так девятьсот пятьдесят один восемьсот двадцать четыре восемьдесят семь двенадцать все правильно все тогда ожидайте звонок от мастера эти не часа и номер повторной заявки у вас будет сто двадцать четыре семьдесят два двадцать можно не записывать всего хорошего до свидания
# 518                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              спасибо за ожидание значит на завтра я вам значит прямо сейчас делаю повторный вызов сколько вы за ремонт заплатите сколько за ремонт заплатили значит сейчас вам делаю повторный вызов массы с вами созвониться в течение часа с ним уже все обсудите так и поспишь ну ма нет но я вам сейчас пока делаю повторный вызов по гарантии мастера мастер позвонит вам уже уже с ним обсудите все так что вам чтобы тот же мастер будет конечно тот же так в течение часа мастер вам позвонить так девятьсот пятьдесят один восемьсот двадцать четыре восемьдесят семь двенадцать все правильно все тогда ожидайте звонок от мастера эти течение часа и номер повторной заявки у вас будет сто двадцать четыре семьдесят два двадцать можно не записывать всего хорошего до свидания
# 519                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        что что я не понял беда три тысячи да как-как обсудят мне мопед тоже платить придётся да а тот же другой будет пора хорошо когда такое время когда ждать да да да да все правильно хорошо хорошо спасибо большое потом на пике все равно не запомню хорошо хорошо до свидания спасибо
# 527                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       благодарю хорошего дня
# 526                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               спасибо за ожидание до мастера я не дозвонилась сейчас буду связываться с бригадиром заявочку вашу на контроль взяла до одиннадцати часов отзвонимся вам обязательно всего доброго до свидания
# 525                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  я его ожидаю с понедельника
# 529                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      доброе утро сервисный центр оператора и короче я могу вам помочь айсберг что у вас продиктуйте пожалуйста номер телефона я найду заявку передам мастеру что вы ждёте звонка не могу сказать я же не мастермен я я ж говорю да я передам мастеру называть просто номер это пентюх секунду так город зеленоград корпус четыреста тридцать три хорошо я передал мастеру ожидать он вам перезвонит а потом все что вам потом вам перезвонит сейчас секунду трубку не бросайте радиотехнического контроля позвоню ожидайте здравствуйте это отдел контроля ольга вы звонка нашего мастера ожидает да да сейчас оставайтесь на линии сейчас уточню минутку если что соединю вас спасибо за ожидание до мастера я не дозвонилась сейчас буду связываться с бригадиром заявочку вашему контроль взяла до одиннадцати часов отзвонимся вам обязательно всего доброго до свидания
# 528                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               здравствуйте оператор литра этот я в какой сервисный центр попал альбер смотрите кому-то мазер приходил в пятницу там пообещал том что он придёт в понедельник вот и соответственно как бы уже сегодня получается среда ни звонка ни никакой информации от мастера нету а как так получается в понедельник договорились то есть в пятницу был восемь вы там какую-то пометочку поставьте что это от факта хочет восемь девять два шесть пять семь два шесть восемь семь шесть да абсолютно верно ага ага я буду подмогу понимать что вы передали мастеру что до мастера доставите не ну я понял я в понедельник просил эту информацию то есть как бы соответственно донести до мастера это никакой информации не последовало в понедельник не бросаю я его ожидаю с понедельника хорошо благодарю хорошего дня
# 524                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  здравствуйте это отдел контроля ольга вы звонка нашего мастера ожидает сюда дымка да сейчас оставайтесь на линии сейчас уточню минутку если что соединю вас
# 546                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      пятьсот восемьдесят восемь ноль тридцать два да я вчера должен был приехать у меня хвост смотрится легко случился я заявку такого там увидел бывает пожалуйста ладно я поеду через полчаса приехала да завтра у нас четверг да после шести не получится выдал ей заявку меня ждёт давно уже человек а с утра никогда не приехать но оставьте это сама я попробую что-то сделать но пока обещать не могу ну оставьте пока на завтра да да да да потому что даяние у меня есть там заявка но я просто не знаю как у меня получится их не совместить да я уже не обязательно конечно район
# 547                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       утыкались это а ленсовета три четыре корпус три у него минутку знаю нет сегодня ей неудобно за завтра после шести удобно будет с утра никогда а полям пока на завтра да хорошо хорошо я тогда пудовую ей скажу пусть ожидает завтра звонка но в любом случае да позвоните ей завтра все хорошо спасибо
# ...
# 598                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     крылья здравствуйте да здравствуйте сорок восемь шестьсот восемьдесят девять а михаила дудина как вы там были вы когда планируете визитки сегодня после двух кей алло посмотреть клиент все в больнице я не знаю принцип как может каким сыром закрыть ли продлевать я напишу да для комментарии для уток а если будете продлевать все страньше измена да да небось уже сделали все алло не до зонтик закрывает семьдесят первом а вышлю
# 597                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      алло здрасте мне бы заявочку пятьсот восемьдесят шесть сто восемьдесят девять прозвонить в идеале соединить меня конечно если можно пятьсот восемьдесят шесть сто восемьдесят девять если можно соединить нет нам клиент просил перезвонить вообще сегодня после двух в идеале алло ну посмотрим сейчас заявочку в сестрорецке надо прозвониться с номера сказал он пятьсот восемьдесят пять семьсот шестьдесят восемь там недозвоны были не знаю сколько там недозвонов можно позвонить хорошо спасибо
# 593                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         алло посмотрите клиент все в больнице я не знаю принцип как может каким сыром закрыть либо продлевать я напишу да для комментарии для только если будете продлевать все страньше измена да да небось уже сделали все
# 601                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       вот восемьдесят семь девятьсот тринадцать дата у меня вчера должен был приехать он сложилось у меня форс-мажор был это само уточните пожалуйста можно ли ехать без чеки с участком опытом назвать своё в субботу после часа у меня суббота выходной день будет вы я перейдя тогда попрошу чтобы другой подъехал спасибо оставьте хорошо хорошо я тогда все понял спасибо я про конторой вот вопрос спасибо до свидания нет нет все все
# 602                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         утка лизавета как витебске девяносто семь корпус один подождём минуту тоже сегодня не могут просили перенести визит на субботу удобно будет подключаться да тогда я вам тогда пропишу на десятое ноль второе после тринадцати ну просил созвониться по времени соориентировать да пожалуйста больше никаких не будет
# 599                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 тоже сегодня не могут просили перенести визит на субботу удобно будет отличаться да тогда я вам тогда пропишу на десятое ноль второе после тринадцати ну просил созвониться по времени соориентировать да пожалуйста больше никаких не будет
# 600                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   нет в субботу после часа у меня суббота выходной день будет вы я перейдя тогда попрошу чтобы другой подъехал спасибо оставьте хорошо хорошо я тогда все понял спасибо я про вот вопрос спасибо до свидания нет нет все все
# 648                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       это ка татьяна керченская тридцать два что тут хорошо ну нет виктора руб там дурниной может на завтра на утро им только утро надо давайте соединю алло да ну вот сто один мастер только от нехватки компании только один мастер ну ладно сначала тогда кредите все эти объявления народа некому работать ладно понятно
#
#      is_duplicate
# 359         False
# 360          True
# 356         False
# 357         False
# 358          True
# 442         False
# 443          True
# 440         False
# 441          True
# 520         False
# 521          True
# 518         False
# 519          True
# 527          True
# 526         False
# 525          True
# 529          True
# 528         False
# 524         False
# 546         False
# 547          True
# 544         False
# 545          True
# 558          True
# 557         False
# 559         False
# 560         False
# 573         False
# 574          True
# 571         False
# 572          True
# 582          True
# 581         False
# 584          True
# 583         False
# 591         False
# 592          True
# 589         False
# 590          True
# 596          True
# 595         False
# 594          True
# 598          True
# 597         False
# 593         False
# 601         False
# 602          True
# 599         False
# 600          True
# 648          True

# %%
filtered[filtered.duplicated(subset='linkedid', keep=False)].tail(60)
# Out:
#                   linkedid                                  audio_file_name  \
# 37208  1707486764.16557175          in_5111_2024-02-09-16-54-17rxtx-out.wav
# 37209  1707486764.16557175           in_5111_2024-02-09-16-54-56rxtx-in.wav
# 42956  1707553208.16573145           in_5114_2024-02-10-11-20-09rxtx-in.wav
# 42959  1707553208.16573145          in_5114_2024-02-10-11-20-56rxtx-out.wav
# 47617  1707569055.16583959          in_5111_2024-02-10-15-45-42rxtx-out.wav
# 47618  1707569055.16583959           in_5111_2024-02-10-15-47-52rxtx-in.wav
# 49100  1707575044.16587222           in_5111_2024-02-10-17-25-48rxtx-in.wav
# 49102  1707575044.16587222           in_5111_2024-02-10-17-26-30rxtx-in.wav
# 51686  1707631726.16595077           in_5108_2024-02-11-09-08-47rxtx-in.wav
# 51688  1707631726.16595077           in_5108_2024-02-11-09-10-33rxtx-in.wav
# 56108  1707649691.16605902           in_5109_2024-02-11-14-09-39rxtx-in.wav
# 56110  1707649691.16605902           in_5109_2024-02-11-14-10-41rxtx-in.wav
# 57787  1707656561.16610286           in_5108_2024-02-11-16-04-28rxtx-in.wav
# 57789  1707656561.16610286           in_5108_2024-02-11-16-05-15rxtx-in.wav
# 60805  1707669254.16617428    in_9275445908_2024-02-11-19-34-15rxtx-out.wav
# 60806  1707669254.16617428   in_989779594456_2024-02-11-19-34-41rxtx-in.wav
# 60956  1707671071.16618063     in_9859430696_2024-02-11-20-04-32rxtx-in.wav
# 60959  1707671071.16618063  in_989151443628_2024-02-11-20-05-06rxtx-out.wav
# 63216  1707722140.16626199          in_5113_2024-02-12-10-18-07rxtx-out.wav
# 63217  1707722140.16626199           in_5113_2024-02-12-10-19-18rxtx-in.wav
# 63487  1707722834.16626952           in_5113_2024-02-12-10-36-33rxtx-in.wav
# 63489  1707722834.16626952           in_5113_2024-02-12-10-38-34rxtx-in.wav
# 63844  1707723612.16627842           in_5125_2024-02-12-10-40-13rxtx-in.wav
# 63846  1707723612.16627842           in_5125_2024-02-12-10-41-33rxtx-in.wav
# 66495  1707729932.16633830     in_9672537729_2024-02-12-12-25-33rxtx-in.wav
# 66493  1707729932.16633830           in_5116_2024-02-12-12-27-18rxtx-in.wav
# 67917  1707733184.16637072     in_9060560112_2024-02-12-13-19-45rxtx-in.wav
# 67915  1707733184.16637072           in_5116_2024-02-12-13-22-02rxtx-in.wav
# 68022  1707733436.16637286           in_5116_2024-02-12-13-23-58rxtx-in.wav
# 68024  1707733436.16637286           in_5116_2024-02-12-13-25-51rxtx-in.wav
# 69544  1707737170.16641294           in_5125_2024-02-12-14-26-11rxtx-in.wav
# 69546  1707737170.16641294   in_989219004471_2024-02-12-14-27-15rxtx-in.wav
# 70259  1707739085.16643388           in_5108_2024-02-12-15-01-10rxtx-in.wav
# 70260  1707739085.16643388           in_5108_2024-02-12-15-03-13rxtx-in.wav
# 70839  1707740675.16644944           in_5116_2024-02-12-15-24-36rxtx-in.wav
# 70841  1707740675.16644944           in_5116_2024-02-12-15-25-30rxtx-in.wav
# 72147  1707744494.16648148           in_5116_2024-02-12-16-30-37rxtx-in.wav
# 72149  1707744494.16648148           in_5116_2024-02-12-16-32-53rxtx-in.wav
# 76934  1707803181.16662896          in_5102_2024-02-13-08-48-33rxtx-out.wav
# 76936  1707803181.16662896          in_5102_2024-02-13-08-50-41rxtx-out.wav
# 76944  1707803181.16662896          in_5102_2024-02-13-08-58-58rxtx-out.wav
# 77365  1707805310.16664290          in_5111_2024-02-13-09-22-42rxtx-out.wav
# 77367  1707805310.16664290          in_5111_2024-02-13-09-23-35rxtx-out.wav
# 77371  1707805310.16664290          in_5111_2024-02-13-09-25-34rxtx-out.wav
# 77374  1707805310.16664290           in_5111_2024-02-13-09-27-53rxtx-in.wav
# 77383  1707805310.16664290          in_5111_2024-02-13-09-33-14rxtx-out.wav
# 78251  1707808068.16666779           in_5125_2024-02-13-10-07-49rxtx-in.wav
# 78253  1707808068.16666779           in_5125_2024-02-13-10-09-08rxtx-in.wav
# 80025  1707812860.16670665           in_5124_2024-02-13-11-28-48rxtx-in.wav
# 80028  1707812860.16670665          in_5124_2024-02-13-11-29-12rxtx-out.wav
# 80378  1707813716.16671454          in_5124_2024-02-13-11-43-01rxtx-out.wav
# 80380  1707813716.16671454          in_5124_2024-02-13-11-43-47rxtx-out.wav
# 80627  1707814345.16671958     in_9036239400_2024-02-13-11-52-26rxtx-in.wav
# 80626  1707814345.16671958          in_5112_2024-02-13-11-53-48rxtx-out.wav
# 84675  1707824762.16681701          in_5112_2024-02-13-14-46-03rxtx-out.wav
# 84676  1707824762.16681701           in_5112_2024-02-13-14-47-42rxtx-in.wav
# 86534  1707829618.16685999          in_5112_2024-02-13-16-08-29rxtx-out.wav
# 86538  1707829618.16685999          in_5112_2024-02-13-16-12-18rxtx-out.wav
# 88157  1707835275.16690525     in_9806318995_2024-02-13-17-41-16rxtx-in.wav
# 88156  1707835275.16690525          in_5112_2024-02-13-17-43-13rxtx-out.wav
#
#               record_date  model   side           src   dst  \
# 37208 2024-02-09 16:54:17      0   True          5111  main
# 37209 2024-02-09 16:54:56      0  False          5111  main
# 42956 2024-02-10 11:20:09      0  False          5114  main
# 42959 2024-02-10 11:20:56      0   True          5114  main
# 47617 2024-02-10 15:45:42      0   True          5111  main
# 47618 2024-02-10 15:47:52      0  False          5111  main
# 49100 2024-02-10 17:25:48      0  False          5111  main
# 49102 2024-02-10 17:26:30      0  False          5111  main
# 51686 2024-02-11 09:08:47      0  False          5108  main
# 51688 2024-02-11 09:10:33      0  False          5108  main
# 56108 2024-02-11 14:09:39      0  False          5109  main
# 56110 2024-02-11 14:10:41      0  False          5109  main
# 57787 2024-02-11 16:04:28      0  False          5108  main
# 57789 2024-02-11 16:05:15      1  False          5108  main
# 60805 2024-02-11 19:34:15      0   True    9275445908  5164
# 60806 2024-02-11 19:34:41      0  False  989779594456  main
# 60956 2024-02-11 20:04:32      0  False    9859430696  5164
# 60959 2024-02-11 20:05:06      0   True  989151443628  main
# 63216 2024-02-12 10:18:07      0   True          5113  main
# 63217 2024-02-12 10:19:18      0  False          5113  main
# 63487 2024-02-12 10:36:33      0  False          5113  main
# 63489 2024-02-12 10:38:34      0  False          5113  main
# 63844 2024-02-12 10:40:13      0  False          5125  main
# 63846 2024-02-12 10:41:33      0  False          5125  main
# 66495 2024-02-12 12:25:33      0  False    9672537729  5116
# 66493 2024-02-12 12:27:18      0  False          5116  main
# 67917 2024-02-12 13:19:45      1  False    9060560112  5034
# 67915 2024-02-12 13:22:02      0  False          5116  main
# 68022 2024-02-12 13:23:58      0  False          5116  main
# 68024 2024-02-12 13:25:51      0  False          5116  main
# 69544 2024-02-12 14:26:11      0  False          5125  main
# 69546 2024-02-12 14:27:15      0  False  989219004471  main
# 70259 2024-02-12 15:01:10      0  False          5108  main
# 70260 2024-02-12 15:03:13      0  False          5108  main
# 70839 2024-02-12 15:24:36      1  False          5116  main
# 70841 2024-02-12 15:25:30      0  False          5116  main
# 72147 2024-02-12 16:30:37      0  False          5116  main
# 72149 2024-02-12 16:32:53      0  False          5116  main
# 76934 2024-02-13 08:48:33      0   True          5102  main
# 76936 2024-02-13 08:50:41      0   True          5102  main
# 76944 2024-02-13 08:58:58      0   True          5102  main
# 77365 2024-02-13 09:22:42      0   True          5111  main
# 77367 2024-02-13 09:23:35      0   True          5111  main
# 77371 2024-02-13 09:25:34      0   True          5111  main
# 77374 2024-02-13 09:27:53      0  False          5111  main
# 77383 2024-02-13 09:33:14      0   True          5111  main
# 78251 2024-02-13 10:07:49      0  False          5125  main
# 78253 2024-02-13 10:09:08      0  False          5125  main
# 80025 2024-02-13 11:28:48      0  False          5124  main
# 80028 2024-02-13 11:29:12      0   True          5124  main
# 80378 2024-02-13 11:43:01      0   True          5124  main
# 80380 2024-02-13 11:43:47      0   True          5124  main
# 80627 2024-02-13 11:52:26      0  False    9036239400  5112
# 80626 2024-02-13 11:53:48      0   True          5112  main
# 84675 2024-02-13 14:46:03      0   True          5112  main
# 84676 2024-02-13 14:47:42      0  False          5112  main
# 86534 2024-02-13 16:08:29      0   True          5112  main
# 86538 2024-02-13 16:12:18      0   True          5112  main
# 88157 2024-02-13 17:41:16      0  False    9806318995  5112
# 88156 2024-02-13 17:43:13      0   True          5112  main
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# 37208                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       а ездит в руководстве по залу я попросил дать мне припарковаться
# 37209                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       шлагбаум подъедете заберёте но не факт что место будет во дворе да всего доброго
# 42956                                                                                                                                                                                                                                                                                                                                                                                                                                                                 здесь внизу сервисный центр здравствуйте подскажите пожалуйста в какое время удобно будет чтоб мастер к вам приехал по звонкам в три часа хорошо ждать
# 42959                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           сто сто ноль позвоните позвонить за час правильно или уже нет хорошо спасибо
# 47617                                                                                                                                                                                                                                                                                                                                                                                                                                                               да давайте другую и тогда двести пятнадцать ноль три девяносто пять спросите минут через пятнадцать двадцать смогут принять а то там написано после пяти
# 47618                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    да ну чеченина вас ждут минут через двадцать тридцать всего доброго
# 49100                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       нова добрая оставайтесь на линии сейчас у мастера уточню давайте
# 49102                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    мастер в районе семи вечера будет у вас всего добро
# 51686                                                                                                                                                                                                                                                                                                                                                                                                                                      добрый день следственный центр беспокоит оставляли заявочку на ремонт телевизора мастер к вам не смог дозвониться сейчас удобно будет поговорить дню минутку оставайтесь на линии
# 51688                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   спасибо большое за ожидание у мастера занят телефон отправлю ему сообщение чтобы он вам перезвонил ожидайте звоночка
# 56108                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              а какая татьяна здравствуйте у вас куча не на дом шесть сейчас соединю с мастером минутку
# 56110                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        но к сожалению не удалось дозвониться до мастера оставила ему сообщение ожидайте он вам перезвонит да все добро
# 57787                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         так номер машины две цифры толкнув сорок восемь хорошо чесменку перед домом он закажет пропуск
# 57789                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     все, вас ожидают, можете подъезжать.  пропуск вам сейчас закажут.  да, пожалуйста.
# 60805                                                                                                                                                                                                                                                                                                                                                                                                                 да слышь здравствуйте вызываемый вами абонент сейчас не отвечает возможно на его телефоне включён беззвучный режим или он не может взять трубку пожалуйста попробуйте перезвонить позднее или оставьте
# 60806                                                                                                                                                                                                                                                                                                                                                                                                                      а здравствуйте а вызываемый вами абонент сейчас не отвечает возможно на его телефоне включён беззвучный режим или он не может взять трубку пожалуйста попробуйте перезвонить позднее или оставьте
# 60956                                                                                                                                                                                                                                                                                                                                                                                                                                                                         аля подожди масть в заявке двести четырнадцать девяносто два ноль шесть алло здравствуйте это мастер буду в течение тридцати минут до свидания
# 60959                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 алло здравствуйте это мастер буду в течение тридцати минут до свидания
# 63216                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               у тебя ещё одна двести пятнадцать десять восемьдесят семь да то же самое
# 63217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         здесь все в порядке перенесла на завтра пожалуйста до свидания
# 63487                                                                                                                                                                                                                                                                                                                         не знаю слушайте она ушла трубку видимо положила и ушла куда-то искать модель машинки ну не знаю я что делать с вами соединить когда вернётся здесь надо без вариантов все-таки потому что и выезд тут и модель машины уточнить но сейчас сейчас подождите вернусь к ней висите на линии тогда
# 63489                                                                                                                                                                                                                                                                                                                                                               шерстяной она вообще совести нет никакой просто сейчас если звонок её сбросить на хату мы потом вообще не дозвонимся эта трубка так и останется лежать давайте я вас сейчас соединю подождёте скажите и але она все поймёт что это выдавайте перекидываю
# 63844                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  о здрасте сервисный центр вас беспокоит по поводу заявочки на смету квартиры с мастером удобно сидят вас минуту ждать
# 63846                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          алло мастер сейчас занят минутку перезвонит вам хорошо всего доброго отстанет
# 66495                                                                                                                                                                                                                                                                                                                                                                                                    и все добрый день мастер данилюк воронеж заявочка сто двадцать четыре семьдесят пять сорок три да там что-то до клиента дозвониться не могут попробуйте если кто-то буду закрывать её как отказ ну все хорошего дня
# 66493                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 юрий не берут можете закрыть семьдесят один пожалуйста
# 67917   светлана, здравствуйте  хотели вызвать мастера для машины  для стиральной машины  да, оставляли  да  ну вот на этот же номер  8-906-056-01-12  нет, не приезжал  у нас никого не было, поэтому мы еще раз и звоним  звонил?  звонил, сказал, вам перезвоню  ну вот  он сказал, в течение двух недель перезвоню  но нам больше никто не перезвонил  и мы решили, нам нужно как бы решить вопрос с машиной  не дозвонился  нам никто не звонил  или это другой мастер?  здравствуйте  завтра?  завтра, пожалуйста  а примерно в какое время, вы только скажите?  с 12 до 4  хорошо, спасибо  все, до свидания, спасибо
# 67915                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 отдел контроля здравствуйте как-то ваш адрес минуточку пожалуйста мастер наш сегодня дозвонился до вас
# 68022                                                                                                                                                                                                                                                                                                                                                                                                                              составьте относятся ко лбу здравствуйте сервисный центр скажите пожалуйста мастер наш дозвонился до вас по мелкооптовым и сервиса сверлили отверстие оставайтесь на я воссоединюсь сейчас
# 68024                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      спасибо создание к сожалению телефон мастера сейчас занят он чуть попозже вам наперёд до свидания
# 69544                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    алло здравствуйте сервисный центр вас беспокоит оставляли заявочку на телевизор с мастером удобно связаться минутку
# 69546                                                                                                                                                                                                                                                                                                                                                  да добрый день ну смотрите аппарат готов вас будет час в принципе могу завести вы дома будете ну смотрите я перед выездом должен позвонить вам ещё имеете в виду так что подходите к телефону если не подойдёте то я к вам не поеду поняли да для чего тогда на связи
# 70259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     добрый день сервисный центр оставайтесь на линии уточним у мастера время вечеринку
# 70260                                                                                                                                                                                                                                                                                                                                                                                                                                                                       спасибо большое за ожидание мастер сейчас на ремонте освободится в течение получаса вам перезвонит по времени визита да пожалуйста всего доброго
# 70839                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              здравствуйте сервисный центр с мастером могу соединить вас трубочку не кладите пожалуйста
# 70841                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                спасибо за ожидание я прошу прощения оказывается я дублировал мастер уже довольно дозвонился серая извините до свидания
# 72147                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   отдел контроля здравствуйте никита рыбаков ваш адрес
# 72149                                                                                                                                                                                                                                                                                                                                                                                                                                                                        спасибо ожидание к большому сожалению у меня не получилось дозвониться до мастера отправлю ему сообщение он позвонит вам да в вашем районе один
# 76934                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   у нас сумочку спун а вот я можно вот по заявке двести тринадцать юность пять челюсть
# 76936                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     то сейчас секундочку кроха так двести четырнадцать шестьдесят девять пятнадцать уклонится от суток
# 76944                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      важный период времени опросов частично со мной ну вам там что позвонок ей спасибо
# 77365                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ещё есть у меня изумлял пиздец поехали двести пятнадцать четырнадцать тридцать три с одиннадцати до двенадцати
# 77367                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   да да да ждут да так поехали дальше двести пятнадцать четырнадцать пятьдесят один четырнадцать шестьдесят один садитесь нас сюда час
# 77371                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       двести пятнадцать десять пятьдесят шесть да с двенадцати до двух
# 77374                                                                                                                                                                                                                                                                                                                                                                                                                                          алло сегодня не может завтра четырнадцатого ноль второго с десяти утра утром позвонить по времени договориться комментарий написала пятьдесят девять андропова с часу до трёх
# 77383                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               так лучше двести пятнадцать ноль два двенадцать двести пятнадцать ноль два двенадцать с четырёх до шести
# 78251                                                                                                                                                                                                                                                                                                                                                                                                                                                   алло здравствуйте оставляли заявочку на сайт технические работы заявку оставляли на сантехнические работы с мастером удобно соединю вас разговаривает минуту ожидать
# 78253                                                                                                                                                                                                                                                                                                                                                                                                                                                                извините за ожидание мастер уже связался уже вроде договорились ты же мастер связывался договорился всего доброго да до свидания хорошо сдайте те добро
# 80025                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       вот такая там не может так долго ждать там вскрытие ещё двух-трех сейчас секунду
# 80028                                                                                                                                                                                                                                                                                                                                                                                                                                                                 у тебя отличная и ряде я просто два четыре восемьдесят пять тридцать три да наберите пожалуйста там какой-то нервный человек скажите что я к часу буду
# 80378                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         хорошо дальше так в светлановский пятьсот восемьдесят восемь семьсот восемьдесят шесть скажите где-то через полтора года у них
# 80380                                                                                                                                                                                                                                                                                                                                                                                                                                                                          хорошо дальше ещё один пища ему поменять пятьсот восемьдесят восемь девятьсот восемнадцать да позвоните спросите тома я сегодня не дома вовсе
# 80627                                                                                                                                                                                                                                                                                                                                                                                                                    добрый день мастер заявочка двадцать один пятьдесят один шестьсот двадцать там мне вроде трубочка активно звоню не могу дозвониться чтобы если коста интервьюировала он тогда ли по почте ивановича
# 80626                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            если ты оставим первоединого нам тогда либо почту но не все
# 84675                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             применение установлено пожалуйста подождите алло нет с кем
# 84676                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        спасибо за ожидание и теперь не могу дозвониться до мастера оставил ему сообщение сам перезвонит когда сводится
# 86534                                                                                                                                                                                                                                                                                                                                                                                          так так сейчас секундочку солнце он как ещё один виноград андреевский только после шести часть от двадцать карт ага ну десять минут двести пятнадцать ноль девять ноль ноль восемь девять девяносто три да в течение получаса
# 86538                                                                                                                                                                                                                                                                   ё-моё так сейчас секундочку таня солнечную андреевка андреевка для духовки и закрывается за визит девятнадцать общая роль так сейчас секундочку двести двести двести двести пятнадцать унций двадцать семь как произнесла бауму летом в течение получаса танец по счету когда шлагбаум пожалуйста на ну она с девятнадцати но я рядом смысл секретно
# 88157                                                                                                                                                     двести пятнадцать двадцать ноль два оппа подождите у них дата выдала восемнадцатого прошу прощения подождите не выключайтесь пожалуйста тогда тогда у нас двести пятнадцать двадцать семнадцать полезно у них тоже завтра да он вернётся так и гонять вообще быть он нашёл двести пятнадцать восемнадцать девяносто четыре ага потом там нет не поедешь точно узнайте ожидает нет не получится вот видите как в точку попали у посылок лучше чем вообще не попасть
# 88156                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      вот видите как в точку попали посылок лучше чем вообще не попасть
#
#        text_length
# 37208           64
# 37209           80
# 42956          150
# 42959           76
# 47617          152
# 47618           67
# 49100           64
# 49102           51
# 51686          177
# 51688          116
# 56108           89
# 56110          111
# 57787           94
# 57789           83
# 60805          198
# 60806          193
# 60956          142
# 60959           70
# 63216           72
# 63217           62
# 63487          286
# 63489          248
# 63844          117
# 63846           77
# 66495          211
# 66493           54
# 67917          597
# 67915          102
# 68022          185
# 68024           97
# 69544          115
# 69546          261
# 70259           82
# 70260          144
# 70839           90
# 70841          119
# 72147           52
# 72149          143
# 76934           84
# 76936           98
# 76944           81
# 77365          110
# 77367          132
# 77371           64
# 77374          173
# 77383          104
# 78251          164
# 78253          151
# 80025           80
# 80028          150
# 80378          126
# 80380          141
# 80627          195
# 80626           59
# 84675           58
# 84676          111
# 86534          221
# 86538          340
# 88157          450
# 88156           65

# %%
summarized.info()
summarized[summarized.duplicated(subset='linkedid', keep=False)].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73089 entries, 0 to 90690
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   linkedid         73089 non-null  object
#  1   audio_file_name  73089 non-null  object
#  2   record_date      73089 non-null  datetime64[ns]
#  3   model            73089 non-null  int64
#  4   side             73089 non-null  bool
#  5   src              73089 non-null  object
#  6   dst              73089 non-null  object
#  7   text             73089 non-null  object
#  8   text_length      73089 non-null  int64
# dtypes: bool(1), datetime64[ns](1), int64(2), object(5)
# memory usage: 5.1+ MB
#                linkedid  \
# 0   1707265060.16457066
# 1   1707265060.16457066
# 6   1707270147.16457217
# 7   1707270147.16457217
# 10  1707271464.24552551
#
#                                                                  audio_file_name  \
# 0                                         in_5056_2024-02-07-03-17-43rxtx-in.wav
# 1                                        in_5056_2024-02-07-03-17-43rxtx-out.wav
# 6                                   in_9139901988_2024-02-07-04-42-29rxtx-in.wav
# 7                                  in_9139901988_2024-02-07-04-42-29rxtx-out.wav
# 10  a2024-02-07t05:04:24b_c9232212227d_e9134862910f_g1707271464.24552551h-in.wav
#
#            record_date  model   side         src         dst  \
# 0  2024-02-07 03:17:43      0  False        5056        main
# 1  2024-02-07 03:17:43      0   True        5056        main
# 6  2024-02-07 04:42:29      0  False  9139901988        5056
# 7  2024-02-07 04:42:29      0   True  9139901988        5056
# 10 2024-02-07 05:04:24      0  False  9232212227  9134862910
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            доброе утро беспокоит вас сервисный центр оператора наталья звонили нам сейчас могу вам чем-то помочь и пропустить звонок это ремонт у нас бытовой техники ну вы я вас поняла будет необходимо обращайтесь извините всего доброго всего доброго до свидания
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              а про я не помню её названия я знаю лерою мне коробка мне
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    просьба скрыть от телефона ремонтируете так надо конечно слушать как а у тебя дисплей на айфоне десятом поменять есть не печи ну да дисней дисней так надо игорь да в этом как яндекс айфон десять сейчас моменте можно этот решить вопрос да или нет если нет дальше буду искать телефон нужен срочно все хорошо хорошо буду знать когда девятьсот тринадцать девятьсот девяносто девятнадцать восемьдесят восемь на богдана хмельницкого увидел рассердив на богдана хмельницкого на богдана хмельницкого который у вас сервис я заеду если что ну близок богдана хмельницкого где-то я же не просто так же номер телефона взял да без разницы какой номер дома без разницы я увидел просто сервис ваш здесь недалеко поэтому позвонил да да поставьте любой номер дома поставьте десять тетрадей
# 7   здравствуйте сервисный центр операторная туалет чем могу вам помочь телефон вы имеете в виду сотовый мобильный да да да как у нас называется не подскажите как называется не подскажите так мы этот смартфон у вас даст смартфон а что нужно поменять стекло вы имеете в виду да подскажите пожалуйста как я могу к вам обращаться игорь находитесь в новосибирске да в черте города а наш телефон посмотрели в какой рекламе магнитной карты у вас наша на магнитной карте в интернете посмотрели я вас поняла игорь по поводу стекла как он у вас называется смартфон не подскажите десятый так по поводу смартфон телефон по поводу телефон вашего мастер вам может перезвонить сначала наш в течение ближайших двух часов вы с мастером сможете ещё раз всех вот точно нить обговорить да нет но это нужно с мастером переговорить мастер перезванивает вот я по пошиву как можно быстрее чтобы он вам перезвонил вы с ним все обговариваете оставите координаты ваши телефоны и адреса можете с вашего участка перезвонит который вашу улицу обслуживает а находитесь вы что в мастеру мы подобрали ближайшего к вам в котором богдана хмельницкого номер дома это наверное не наш сервис потому что у нас нет на богдана хмельницкого сервиса богдана хмельницкого и номер думаю этого будет достаточно потому что у нас мастера одну улицу некоторые разные обслуживают так у вас девятьсот тринадцать девятьсот девяносто девятнадцать восемьдесят восемь телефон да и я боюсь у меня просто компьютер мы должны поставить номер дома или название улицы иначе компьютер просто не возьмёт вашу заявку хорошо номер десять если сумма сюртука тогда подскажите правильный адрес ожидайте звонка перезвонит в ближайшее время
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             алло здравствуйте мастер звонит вам установка чего там так ага а тот есть а тот есть для него отвод да кран кран кран ну да да да то есть надо смотреть правильно смотреть надо я подъеду наверное в обед или после обеда вы так отлично отлично отлично давайте после двух я вам заранее позвоню хорошо надо посмотреть ну наверно в районе трёх тысяч будет стоить догнал посмотри сначала посмотреть там может этот что там мне не растягивать не будем это по-любому растягивать не будем я посмотрю то есть ну и вам сразу скажу когда что я смогу это сделать и сколько времени займёт пойдёт такой рассказ а именно сегодня полностью после двух даст да у меня есть инструмент сейчас я его с собой знать это знак стоп стоп стоп значит это другому мастеру отдали я я звоню сразу это другому мастеру отдали дать опыт но я понял понял вчера вчера я вообще был свободный весь день нет нано ну хорошо хорошо все все до связи
#
#     text_length
# 0           251
# 1            57
# 6           771
# 7          1668
# 10          905

# %%
# summarized.to_csv('summarized_transcripts.csv', index=False)
summarized = pd.read_csv(
    'summarized_transcripts.csv',
    parse_dates=[2],
    dtype={'linkedid': 'object'}
)

# %%
summary = pd.DataFrame()
summary[['linkedid', 'text']] = summarized[['linkedid', 'text']]

# %%
client = OpenAI(api_key='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')#os.environ["OPENAI_API_KEY"])

def generate_summary(text):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-1106",
        seed=SEED,
        messages=[
            {"role": "system", "content": "Выдели из полученного текста только важные для сервисного центра по ремонту бытовой техники, куда обращается клиент данным текстом, фразы с вопросами, запросами клиента, только когда он хочет что-то выяснить, обращается по поводу какой-то проблемы, заявляет о ней. НЕ ВЫВОДИ НЕНУЖНЫЕ ДЕТАЛИ, такие как адреса, время, телефоны, номера и тому подобное. ПЕРЕЧИСЛЕННОЕ - ЛИШНЯЯ ИНФОРМАЦИЯ. Твоя конечная цель - донести до руководства, с какими запросами от клиентов в первую очередь сталкиваются сотрудники компании. Выводи одной строкой, но состоящей из ОТДЕЛЬНЫХ уникальных предложений, каждое из которых будет содержать весь необходимый контекст, чтобы взглянув на предложение, можно было понять, о чём речь, не видя остальных прердложений. Для этого сначала перефразируй каждую фразу в отдельное предложение так, чтобы оно выглядело понятным и самодостаточным, но используй только исходную смысловую информацию во всём тексте, не придумывай НИКАКУЮ свою. ТОЛЬКО если ты не можешь выделить требуемую информацию, вместо самостоятельно генерируемого ответа выводи: Нет ключевой информации."},
            {"role": "user", "content": "але але да але але да да да сегодня бедняки да подъезжайте нет проблем да да да но вы поняли что у нас каждая дверь морозильной камеры или сама русловая уплотнительная резинка нужда нет ну в этот самый раз и фрагменты и у неё там ну вы же только бутылку хотите посмотреть ничего не делая как я вам могу скинуть размеры я в интернете смотрела да хорошо хорошо проще."},
            {"role": "assistant", "content": "У нас проблема с уплотнительной резинкой или дверью морозильной камеры. Вы только бутылку хотите посмотреть, как я могу вам передать размеры?"},
            {"role": "user", "content": text}
        ]
    )
    return response.choices[0].message.content

def compute_scores(row):
    P, R, F1 = score(
        [row['result']],
        [row['text']],
        lang="ru"
    )
    return pd.Series([P.item(), R.item(), F1.item()])

# %%
# summary['result'] = summary['text'].apply(generate_summary)
# summary[[
#     'precision',
#     'recall',
#     'f1'
# ]] = summary.apply(compute_scores, axis=1)
summary[['text', 'result']].sample(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    text  \
# 3131        алле здрасте я по поводу ремонта электропечи там и бытовой техники я правильно с вами да смотрите мне такая история я тут вызывал мастера вот он не чинил у меня или электроплита там ломалась то есть дефекты не греет конфорка он не починил как бы это вот наряд заказ да так он тут вы и сейчас я попробую прочитать двести четырёх одеться шестнадцать но в принципе могу достать телефон девятьсот шестнадцать один три один четыре пять ноль три один три один сорок пять ноль три совершенно верно да мастер храп щенков кажется а вот она опять перегорела да штучка во мне сказал стопам гарантийный срок есть да не а он объяснит платить не надо да будет хорошо то есть я жду за переключение да давайте да наталья меня зовут андрей да совершенно верно опять горела а это тот же будет или другой какой-то а это николай иванович четыре как вас зовут анализ звони я таня храпченко кажется и она а ну давайте я начну это сейчас перезвонить предметам в течение дня а хорошо спасибо сбербанка да пасибо
# 793                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          в настоящее время вызов невозможен по техническим причинам
# 388                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    здравствуйте нам нужен сантехник сантехник нужен нам вера она с унитаз подтекает бачок нет нет не впервые да впервые ростов на дону укажите пожалуйста не подскажу волкова сорок один сто девятнадцать второй подъезд восьмой этаж да да вот этот не высвечивается у вас восемь девятьсот восемь сто восемьдесят восемь восемьдесят один ноль ноль шесть спасибо
# 531    да, вы мне обещали в 11 позвонить, и так и не позвонили.  мне пришлось уже в ваш центр звонить, жаловаться.  я сказала, нет, я сказала в 11, я уже буду на связи.  в 10, в 10.30 в 11.  ага, а вы во сколько приедете?  через полтора. давайте тогда через полтора, вот так вот, не раньше.  пол второго.  ну, давайте, просто у меня там будет промежуточек, у меня такой промежуточный интервал пол второго, да?  ну, давайте, только, ну, вы посмотрите, вот так тогда.  46? да, 4-6.  четвертый подъезд, третий, третий подъезд, четвертый этаж.  46, ключ 51-70.  нет, я не смогу запустить, у меня нет брелка.  у нас есть парковки такие около, ну, вот на третьей фрунзенской здесь есть они парковки.  угу.  ну, вы тогда, когда вот будете, можете позвонить за минут 15-20, потому что я здесь не, я же не дома сижу, я на участке, но просто я могу подойти, мне надо вот просто время понимать, понимаете?  сейчас я сейчас в пределах 15-20 минутах вот так нахожусь.  ага, все, давайте, жду вас.  ага.  спасибо.
# 1466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   о, и звонили меня.  на какую?  нет, нет, все уже у меня ремонтировано.  угу, угу.  о, понял.  нет, нет, все уже.
#
#                                                                                                                                                                                                                                                                                       result
# 3131                                                                                                           Клиент обращается по поводу ремонта электрической плиты, которую мастер не починил. Он спрашивает о гарантийном сроке и ожидает перезвонка для уточнения дальнейших действий.
# 793                                                                                                                                                                                                                                                                 Нет ключевой информации.
# 388                                                                                                                                                                                      Клиент обращается к сервисному центру с просьбой о вызове сантехника для устранения течи в унитазе.
# 531   Вы обещали мне позвонить в 11, но так и не позвонили. Я уже звонила в ваш центр, жаловалась. Так как вам придется приехать через полтора часа, давайте встретимся в 46 ключ 51-70, на третьем этаже в третьем подъезде. Позвоните за 15-20 минут до приезда, так как я не всегда дома.
# 1466                                                                                                                                                                                                                                                                Нет ключевой информации.

# %%
# summary.to_csv('summary.csv', index=False)
# summary = pd.read_csv(
#     'summary.csv',
#     dtype={'linkedid': 'object'}
# )

# %%
def process_text(text):
    text = text.replace('"', '')
    text = text.replace('\n', ' ')
    text = re.sub(r'\b\d\.\s*', '', text)
    text = re.sub(r'(?<=[\.?])\s+', '', text)
    text = re.sub(r'(?<!\s)-\s', '', text)
    fragments = re.split(r'(?<=[\.?])', text)
    fragments = [frag.lstrip() for frag in fragments if frag.strip()]
    return fragments

# %%
# summary = summary[~summary.result.str.contains(
#     'нет ключевой информации|не удалось выделить ключевую информацию|никакого разговора не состоялось',
#     case=False
# )].reset_index(drop=True)

# fragments = summary.result.apply(process_text)
# clean = pd.DataFrame({
#     'linkedid': summary.linkedid.repeat(fragments.apply(len)).values,
#     'text': [frag for list in fragments for frag in list]
# })
# clean = clean[~clean.text.str.contains(
#     'адрес|город|метро|дом|квартир|подъезд|домофон|этаж|мой телефон|наш телефон|мой номер|номер телефона|номер заявки|номер заказа|телефон для связи|контактный номер|контактный телефон|спасибо|до свидания',
#     case=False
# )]
# clean = clean[clean.text.str.contains(
#     r'[а-яА-ЯёЁ]',
#     regex=True
# )].reset_index(drop=True)

clean['text'].to_frame().sample(10)
# Out:
#                                                                                                                                    text
# 1339                                                                                                                 Когда вы приедете?
# 2392                                                                                      Нам как-то обычно звонят накануне или в день.
# 8069  Мне не понравилась цена за диагностику и ремонт, потому что мастер ничего не объяснил, а за 15 минут работы запросил 6100 рублей.
# 2175                                                           Мастер обещал помочь нам с ремонтом декомплектации барочной поверхности.
# 6499                                                                                        Я пенсионерка, мне сложно сейчас заплатить.
# 8976                                                         Я даже не открыла машину, а мне уже говорят, что нужно заплатить 4 тысячи.
# 900                                                                                   Могу ли я купить и установить тэн самостоятельно?
# 9088                  Мне нужно уточнить, чините ли вы холодильники, и решить вопрос со временем, так как меня не будет какое-то время.
# 8587                                                                             Вы говорите мне более-менее, а то я ничего не понимаю.
# 8381                                                                                                  У нас холодильник вышел из строя.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained('cointegrated/rubert-tiny2')
model = AutoModel.from_pretrained('cointegrated/rubert-tiny2').to(device)

def ave_pool(lhs, mask):
    last_hidden_state = lhs.masked_fill(~mask[..., None].bool(), 0.0)
    return last_hidden_state.sum(dim=1) / mask.sum(dim=1)[..., None]

def get_embeddings(df):
    sentences = df['text'].astype(str).tolist()

    bs = 512
    loader = DataLoader(
        sentences,
        batch_size=bs,
        shuffle=False
    )
    embeddings = []
    
    for batch in tqdm(loader, desc='Processing batches'):
        input = tokenizer(
            batch,
            padding=True,
            truncation=True,
            return_tensors='pt'
        ).to(device)

        with torch.no_grad():
            output = model(**input).last_hidden_state

        attention_mask = input.attention_mask

        embedding = ave_pool(output, attention_mask).cpu().numpy()
        embeddings.extend(embedding)

    df['embedding'] = embeddings
    return df

# %%
embeddings = get_embeddings(clean)
embeddings.tail()
# Out:
# Processing batches:   0%|          | 0/19 [00:00<?, ?it/s]
#                  linkedid  \
# 9493  1708026084.16765862
# 9494  1708026084.16765862
# 9495  1708026084.16765862
# 9496  1708026084.16765862
# 9497  1708026084.16765862
#
#                                                                    text  \
# 9493  Машина перестала работать, мотор шумел, сейчас отключена от сети.
# 9494                                         Сколько стоит диагностика?
# 9495                        Когда-то нужно будет договориться о визите.
# 9496                   Если мотор сломался, то гарантия действует, так?
# 9497                               У меня есть документы, чек и прочее.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               embedding
# 9493        [-0.4979679, -0.16442797, 0.36842173, -1.676214, 0.3559669, 0.19501455, -0.42754954, -0.94375217, 0.71071756, 0.011492193, 0.3678645, 0.45247632, 0.5550098, 0.8986785, -0.37330252, -0.6497234, 0.6455413, -0.023895614, -0.61900723, -0.79517746, -0.095056355, 0.9744611, 0.13928863, -0.26286507, 0.85038006, 0.27458072, 0.5151521, 0.019576043, -0.033802614, 0.71436477, -0.38502896, -0.09489034, -0.05438745, -0.10605653, 0.37437785, 0.58846146, 0.014951134, -0.68956316, 0.4838717, -0.12497558, 0.630146, 0.4168074, 0.34916487, -0.34569946, 0.5091611, 0.15328164, -0.37202215, 1.0042703, 0.09382937, -0.16301294, -0.34029534, 0.07011742, -0.07011939, -0.3813418, 0.17086992, -0.26923758, 0.65138745, 0.044585854, 0.032859582, -0.10529827, 0.4048554, 0.3378154, 1.0203592, -0.7453835, 0.71147454, -0.7332988, 0.2426767, 0.2388079, 0.3004897, -0.26576555, 1.1265013, 0.35250518, -0.47162372, -0.8783016, 0.40011892, -0.8526208, 0.008848876, -0.4220984, 0.15422377, 0.27740133, -0.02472756, -0.060771517, 0.085469306, 0.39651388, -0.26952672, -0.6925851, -0.99020034, 0.38377187, -0.21832691, -0.56522065, 0.94754934, -0.22286668, 0.44678244, -0.21607503, 0.8348493, 0.31849736, 0.42448932, 0.19199519, 0.17139351, -0.1333192, ...]
# 9494                [-0.056837603, -0.12828873, -0.33625045, -1.046955, -0.742052, -0.19488113, 0.22727776, -0.24017954, -0.29870102, 0.15916987, 0.19967127, -0.38493606, 0.1942632, 1.7492805, -0.51252276, -0.2938362, 0.67394114, 0.9360674, -0.02574356, 0.30983338, -0.2890269, 0.093564965, 0.06499841, 0.41844738, 1.7331647, -0.1167899, 0.28999856, 1.002111, 1.0973669, 0.31991345, 0.6112205, 0.6071232, -0.58056813, -0.09902742, 0.20809667, 0.2317399, 0.8121771, -0.66393685, -0.33162472, -0.050684024, 0.52022207, -0.4664117, 0.00070955855, -0.48104763, 0.35467634, -0.38893127, -0.2684473, -0.64813644, 0.8216538, 0.57753295, 0.7762627, -0.13106127, 0.126467, -0.803066, 0.31932488, 0.020890161, 0.9325392, -0.012108277, -0.17315097, 0.13772224, 0.5116455, 0.6035383, -0.5713238, -0.07231391, 0.70880765, -0.32310212, 0.19457988, 0.059459537, 0.008304007, 0.812063, -0.33621076, 0.032670736, -0.100996114, -1.4283748, -0.041674387, -0.4458109, 0.44135237, -0.7456446, -0.21751624, -0.33863983, 0.3708571, 0.69676083, 0.63982254, 0.8091388, -0.052450042, 0.47036108, 0.086641334, 1.1323377, 0.8317266, 0.32444116, 0.7054079, -0.8803832, 2.3713877, -0.5089391, -0.6416991, 0.95585537, -0.8994674, 0.6509344, -0.62417156, 0.48268548, ...]
# 9495            [-0.34886098, 0.18420686, -0.5768396, -0.92459494, -0.78742284, 0.50220793, -0.46807793, 0.18856876, -0.37399772, 0.5224119, -1.4303226, -0.041167248, -0.5882059, 0.3538309, -0.5692003, -0.8025748, 0.13674118, 0.022152692, -0.15898712, 0.42838955, -0.27624834, -0.737819, 0.22699803, 0.25646606, -0.043639973, 0.49673915, 0.078524135, 0.6307699, -0.35277545, 0.01750282, 0.048715442, -0.24806349, 0.2411568, 1.1034378, -0.20763181, 0.029430324, 0.34790978, 0.13463302, 0.7428165, 0.30425864, -0.19963543, -0.16240193, 0.9074507, -0.7507849, -0.18571396, 0.6216853, 0.13344882, -0.6508356, 0.06439314, -0.6439723, 0.28477073, -0.2647996, -0.5750727, 0.292665, -0.2901146, 0.18579142, 0.32411054, -0.9447561, -0.71872205, 0.34687603, 0.042852208, 1.061345, 0.5398519, 0.066061795, -0.038888484, -0.35797897, 0.45419025, -0.5580458, -0.20086479, 0.11485183, 0.18719535, 0.077335455, 0.07332005, -1.3662211, -0.46650842, -0.29746965, 0.5333707, -0.632391, -0.2638174, 0.7341757, -0.041143954, 0.35147747, 0.18215121, -0.13019268, 0.18489866, 0.4498696, 0.5402865, 0.2675765, -0.23448847, 0.61529845, -0.3289379, -0.39526638, 2.0416415, 0.23474663, 0.021526262, -0.07774577, 0.1917966, 0.03612532, -0.35060334, 0.052838128, ...]
# 9496         [-0.31864417, -0.27890247, -0.5059125, -1.4831957, 0.22800377, 0.50525, -0.5260134, -0.48002812, 0.9437939, 0.84516436, -1.0372677, 0.027543563, 0.33625177, 0.7416156, 0.40094918, -0.5840792, 0.5009137, 0.0028215097, -0.5036097, -1.213757, 0.46749794, 0.7561475, -0.25839865, -0.20912123, 1.0289592, 0.87855256, -0.2178275, -0.02366028, 0.8014097, -0.22692683, -0.19602229, -0.14931437, -0.20432785, 0.37347105, 0.5417774, 0.80517966, 0.76612407, -0.48394167, 0.4656878, -0.016188521, 0.520936, 0.3479814, 0.5538897, -0.117837474, 0.16664703, -0.13879074, -0.23194078, 0.19024485, 0.2670802, -0.18072757, -0.23107536, -0.42884123, -0.09095006, -0.07580715, 0.4155105, 0.32817733, 0.92370576, -0.15396151, -0.7358697, 0.7238442, -0.11006786, -0.004326504, 0.42297518, -0.65015984, 0.23369513, -0.29056206, 0.058002017, -0.0036683495, -0.50102305, -0.12581703, -0.09847887, -0.17551497, -0.15109722, -0.71596587, 0.40811113, -0.03016415, 0.03562013, -0.11994236, 0.2716184, 1.0148294, 0.12598298, 0.02754094, -0.09212629, 0.55041254, -0.09769571, 0.3511483, 0.4723592, 0.9803202, -0.5024607, -0.34865564, 0.5078043, -0.5231152, 1.7328124, -0.30308014, 0.059215385, 0.25898445, 0.25452235, 0.74762857, -0.3430153, 0.4008558, ...]
# 9497  [0.8516195, 0.21865739, -1.3154403, -0.7069812, 0.09856682, 0.44539574, -1.0531659, -0.06832219, -0.40329182, -0.053285714, -0.20057592, -0.43494102, -0.75635207, 0.3320254, -0.16653854, -1.237341, 0.44699094, -0.43793014, 0.21629596, 0.73894155, -0.5582424, 0.35703394, -0.007001877, -0.96258587, 0.73885745, 0.09270122, 0.25549886, 0.037465762, -0.44867697, -0.023964675, -0.18758659, -0.53644854, 0.16566505, 0.40840006, -0.43563417, 1.3051273, 0.6005733, -0.08545062, 0.3494841, -0.3512324, 0.26857412, -0.390584, 1.2163953, -0.29930755, 0.63676214, 0.05523921, -0.24737209, 0.47763968, -0.38523895, -0.29344693, 0.4009148, -0.11857378, -1.2233856, 0.49697322, 0.03582543, 0.2920246, 0.484302, 0.5175238, -0.37732133, 0.15800782, -0.61245173, 0.41713163, -0.33979356, 0.28074616, -0.16634957, -0.5737716, -0.81776506, 0.15070201, 0.99151933, 0.54743236, -0.17137302, 0.23289126, 0.021066027, -0.42454243, -0.2434722, -0.16225535, -0.32718697, 0.5515762, -0.09423862, -0.16480288, -0.44227174, -0.034356907, -0.4406661, 0.887224, -0.0958989, -0.19552375, 0.18920638, 0.37406585, -0.4569586, -0.0051096734, 0.5384566, -0.9520746, 2.2517684, 0.22888881, -0.27623412, 0.46707422, 0.31639454, 0.70201176, 0.24627633, -0.79800105, ...]

# %%
# embeddings.to_pickle('embeddings.pkl')
# embeddings = pd.read_pickle(
#     'embeddings.pkl'
# )

# %%
matrix = np.stack(embeddings.embedding.values)

best_silhouette_score = -1
best_db_index = np.inf
best_count = None
silhouette_scores = []
db_indexes = []
cluster_sizes_list = []

for count in range(4, 21):
    clusterer = KMeans(
        n_clusters=count,
        max_iter=100,
        init='random',
        n_init=10,
        random_state=SEED,
        algorithm='lloyd'
    )
    clusterer.fit(matrix)
    labels = clusterer.labels_

    cluster_sizes = np.bincount(labels[labels >= 0])
    cluster_sizes_list.append((count, cluster_sizes))
    
    if len(set(labels)) > 1:
        silhouette = silhouette_score(matrix, labels)
        db_index = davies_bouldin_score(matrix, labels)
        
        silhouette_scores.append((count, silhouette))
        db_indexes.append((count, db_index))
        
        if silhouette > best_silhouette_score:
            best_silhouette_score = silhouette
            best_count = count
        
        if db_index < best_db_index:
            best_db_index = db_index
            best_count_db = count

for count, cluster_sizes in cluster_sizes_list:
    print(f"Количество кластеров={count}, размеры кластеров: {cluster_sizes}")

print(
    "Лучшее количество кластеров по силуэту:",
    best_count,
    "с оценкой силуэта:",
    best_silhouette_score
)
print(
    "Лучшее количество кластеров по Davies-Bouldin:",
    best_count_db,
    "с индексом Davies-Bouldin:",
    best_db_index
)

# %%
def generate_topics(df, col, matrix, n_clusters, rev_per_cluster):
    messages = [
        {"role": "system", "content": "Ты - профессиональный маркетолог с многолетним стажем. Ты специализируешься на выявлении и характеризации ключевых особенностей взаимодействия пользователей, клиентов с продуктами компаний, бизнесом. Я готов заплатить тебе за хорошее правильное решение до 200$ в зависимости от его качества. Далее представлены фрагменты диалогов клиентов с сервисным центром по ремонту бытовой техники. Эти фрагменты уже разделены на несколько указанных кластеров. Сформулируй описание, название для каждого кластера так, чтобы легко было понятно, что его выделяет, характеризует среди остальных кластеров. Ответ дай в виде подобной JSON структуры, только с двойными кавычками: {'Кластер 0': 'Название 0', 'Кластер 1': 'Название 1'} и так далее."}
    ]
    message = {"role": "user", "content":""}

    tsne = TSNE(random_state=SEED)
    vis_dims2 = tsne.fit_transform(matrix)

    for i in range(n_clusters):
        cluster_df = df[df[col] == i].reset_index(drop=True)

        cluster_center = vis_dims2[cluster_df.index].mean(axis=0)

        distances = np.sqrt(((vis_dims2[cluster_df.index] - cluster_center)**2).sum(axis=1))

        closest_indices = distances.argsort()[:rev_per_cluster]

        closest_reviews = cluster_df.iloc[closest_indices].text

        reviews = "\n ".join(
            closest_reviews.values
        )
        message["content"] += f"\n Кластер {i}: {reviews} "
    
    messages.append(message)
    
    response = client.chat.completions.create(
        model="gpt-3.5-turbo-1106",
        messages=messages
    )
    topics_json = response.choices[0].message.content

    topics_dict = json.loads(topics_json)
    return topics_dict

# %%
general_clusterer = KMeans(
    n_clusters=4,
    max_iter=100,
    init='random',
    n_init=10,
    random_state=SEED,
    algorithm='lloyd'
)
detail_clusterer = KMeans(
    n_clusters=17,
    max_iter=100,
    init='random',
    n_init=10,
    random_state=SEED,
    algorithm='lloyd'
)
general_clusterer.fit(matrix)
detail_clusterer.fit(matrix)

general_labels = general_clusterer.labels_
detail_labels = detail_clusterer.labels_

embeddings['general_cluster'] = general_labels
embeddings['detail_cluster'] = detail_labels

embeddings['edited_cluster'] = embeddings['detail_cluster'].replace(
    {10: 0, 3: 7, 4: 13, 5: 13, 15: 13}
)

# %%
# embeddings.to_pickle('clustered_transcripts.pkl')
# embeddings = pd.read_pickle(
#     'clustered_transcripts.pkl'
# )

# %%
px.pie(
    embeddings,
    names=embeddings.general_cluster.replace({
        0: 'Проблема с оказанными услугами',
        1: 'Запрос на вызов и уточнение информации о времени и услугах',
        2: 'Запрос на цену и оценку стоимости ремонта',
        3: 'Просьба о прозвоне, уточнение деталей и контактов'
    })
).update_traces(textinfo='percent',).update_layout(
    uniformtext_minsize=36,
    uniformtext_mode='hide',
    width=2200,
    height=900,
    title=dict(
    text='Общие категории обращений',
    x=.5,
    y=.98,
    font_size=50
    ),
    legend=dict(
        font_size=30,
        y=.5,
        yanchor='middle'
    )
)

# %%
px.pie(
    embeddings,
    names=embeddings.edited_cluster.replace({
        0: 'Вопросы о стоимости и оплате услуг',
        1: 'Запросы о способах и возможностях связаться с мастером',
        2: 'Уточнение местоположения проблемы и требуемых услуг',
        6: 'Неудовлетворенность качеством предоставленных услуг и запросы на прекращение сотрудничества',
        7: 'Вопросы о сроках, времени и деталях визита мастера',
        8: 'Запросы о наличии запчастей и техники, а также о ценах',
        9: 'Вопросы о предоставлении квитанций, возможности отмены вызова и других дополнительных услугах',
        11: 'Запросы на перенос визита и другие подобные запросы',
        12: 'Запросы на вызов мастера и уточнение возможности ремонта',
        13: 'Уточнение проблем с бытовой техникой и запросы на ремонт',
        14: 'Запросы на быстрый приезд мастера и оказание услуг',
        16: 'Запросы на перезвон и другие коммуникационные запросы'
    })
).update_traces(textinfo='percent',).update_layout(
    uniformtext_minsize=32,
    uniformtext_mode='hide',
    width=2200,
    height=900,
    title=dict(
    text='Детальные категории обращений',
    x=.5,
    y=.98,
    font_size=50
    ),
    legend=dict(
        font_size=24,
        y=.5,
        yanchor='middle'
    )
)

# %%
general_topics = generate_topics(embeddings, 'general_cluster', matrix, 4, 150)

# %%
detail_topics = generate_topics(embeddings, 'detail_cluster', matrix, 17, 35)

# %%
general_topics = {
    'Кластер 0': 'Проблема с оказанными услугами',
    'Кластер 1': 'Запрос на вызов и уточнение информации о времени и услугах',
    'Кластер 2': 'Запрос на цену и оценку стоимости ремонта',
    'Кластер 3': 'Просьба о прозвоне, уточнение деталей и контактов'
}

# %%
detail_topics = {
    'Кластер 0': 'Вопросы о стоимости и оплате услуг',
    'Кластер 1': 'Запросы о способах и возможностях связаться с мастером',
    'Кластер 2': 'Уточнение местоположения проблемы и требуемых услуг',
    'Кластер 3': 'Запросы о времени и сроках приезда мастера',
    'Кластер 4': 'Запросы о конкретных проблемах с бытовой техникой',
    'Кластер 5': 'Озвучивание проблем и запросы о возможных вариантах решения',
    'Кластер 6': 'Неудовлетворенность качеством предоставленных услуг и запросы на прекращение сотрудничества',
    'Кластер 7': 'Вопросы о сроках, времени и деталях визита мастера',
    'Кластер 8': 'Запросы о наличии запчастей и технике, а также о ценах',
    'Кластер 9': 'Вопросы о предоставлении квитанций, возможности отмены вызова и других дополнительных услугах',
    'Кластер 10': 'Запросы на уточнение стоимости услуг и консультаций',
    'Кластер 11': 'Запросы на перенос визита и другие подобные запросы',
    'Кластер 12': 'Запросы на вызов мастера и уточнение возможности ремонта',
    'Кластер 13': 'Уточнение проблем с бытовой техникой и запросы на ремонт',
    'Кластер 14': 'Запросы на быстрый приезд мастера и оказание услуг',
    'Кластер 15': 'Запросы на уточнение подробностей и возможности решения проблемы',
    'Кластер 16': 'Запросы на перезвон и другие коммуникационные запросы'
}

# %%
encoding = tiktoken.get_encoding('cl100k_base')

# %%
len(encoding.encode(general_topics[0]['content']+general_topics[1]['content']))
# Out:
# 1231

# %%
len(encoding.encode(detail_topics[0]['content']+detail_topics[1]['content']))
# Out:
# 15341
