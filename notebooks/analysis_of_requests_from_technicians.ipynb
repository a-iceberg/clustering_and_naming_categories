# %% [markdown]
# # Анализ обращений мастеров

# %%
import json
import sys
sys.path.append('..')

import qa_extract
import pandas as pd
import plotly.io as pio

from tools.text_conversion import clean_json, parse_data
from tools.clusterization import llm_clusterization, plot_clusters

pd.set_option('display.max_colwidth', None)
pio.renderers.default = 'notebook_connected'

SEED = 654321

# %%
res = qa_extract.main()

with open('../data/qa.json', 'r') as f:
    qa = json.load(f)

clean_qa = clean_json(qa)

# %%
clusters = llm_clusterization(clean_qa, 'gpt-4-1106-preview', SEED)

with open('../data/clusters.json', 'w', encoding='utf-8') as f:
    json.dump(clusters, f, ensure_ascii=False, indent=4)
with open('../data/clusters.json', 'r') as f:
    clusters = json.load(f)

clusters
# Out:
# {'Проблемы с загрузкой и отображением фото': ['3',
#   '30',
#   '34',
#   '38',
#   '41',
#   '48',
#   '53',
#   '79',
#   '82',
#   '84',
#   '98',
#   '113',
#   '142',
#   '158'],
#  'Сбой в приложении и UI-оптимизация': ['7', '9', '68', '148'],
#  'Потребность в обновлении приложения': ['13', '129', '153'],
#  'Некорректная работа комментариев к заявкам': ['17', '65', '89', '93'],
#  'Технические вопросы про использование приложения': ['25'],
#  'Чрезмерный расход заряда батареи': ['27', '36'],
#  'Вопросы по переносу заявок и навигации в приложении': ['75'],
#  'Проблема с уведомлениями': ['59', '62', '133'],
#  'Сложности со связью и звонками': ['72', '116', '125']}

# %%
cluster_map = {id_: name for name, ids in clusters.items() for id_ in ids}

rows = []
for item in qa:
    for key, value in item.items():
        if key.startswith('Answer'):
            question_id = key.split(' ')[1]
            affilate, division, device = parse_data(value, 'affilate', 'division', 'device_model')
            cluster_name = cluster_map.get(question_id, 'Нет ответа')
            rows.append(
                {
                    'id': question_id,
                    'affilate': affilate,
                    'division': division,
                    'device': device,
                    'cluster': cluster_name,
                }
            )

df = pd.DataFrame(rows)
df.device = df.device.str.title()
df
# Out:
#      id affilate division   device  \
# 0     3     None     None     None
# 1     7      МСК       ХД  Samsung
# 2     9     None     None     None
# 3    13     None     None     None
# 4    17      СПБ       СМ   Xiaomi
# 5    25     None     None     None
# 6    27      МСК       ХД  Samsung
# 7    30      СПБ       СМ  Samsung
# 8    34     None     None     None
# 9    36     None     None     None
# 10   38      СПБ       СМ   Xiaomi
# 11   41     None     None     None
# 12   48      МСК       ХД   Xiaomi
# 13   51      МСК      МБС   Realme
# 14   53      МСК      УСТ  Samsung
# 15   59      СПБ       ТВ  Samsung
# 16   62      МСК       ХД  Samsung
# 17   65      МСК       ХД  Samsung
# 18   68     None     None     None
# 19   72     None     None     None
# 20   75      МСК       СМ   Xiaomi
# 21   79      СПБ       ТВ  Samsung
# 22   82      ЕКБ       СМ  Infinix
# 23   84      МСК       ПЛ  Samsung
# 24   89     None     None     None
# ...

# %%
df.to_csv('../tables/mrm_clusters.csv', index=False)
df = pd.read_csv('../tables/mrm_clusters.csv')

# %%
df.cluster.value_counts().to_frame().reset_index()
# Out:
#                                                cluster  count
# 0             Проблемы с загрузкой и отображением фото     14
# 1                   Сбой в приложении и UI-оптимизация      4
# 2           Некорректная работа комментариев к заявкам      4
# 3                  Потребность в обновлении приложения      3
# 4                             Проблема с уведомлениями      3
# 5                       Сложности со связью и звонками      3
# 6                     Чрезмерный расход заряда батареи      2
# 7     Технические вопросы про использование приложения      1
# 8                                           Нет ответа      1
# 9  Вопросы по переносу заявок и навигации в приложении      1

# %%
cluster_plot = plot_clusters('Типы обращений', df, 'cluster', 36, 30)
cluster_plot.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df.affilate.value_counts(dropna=False).to_frame().reset_index()
# Out:
#   affilate  count
# 0      МСК     14
# 1      NaN     13
# 2      СПБ      5
# 3      ЕКБ      3
# 4      НСК      1

# %%
affilate_plot = plot_clusters(
    'Филиалы обращений', df, 'affilate', 36, 40, {None: 'Не выгружен'}
)
affilate_plot.show()
# Out:
# <div>                            <div id="37844aef-5de5-4289-9ab5-1a466d355fad" class="plotly-graph-div" style="height:900px; width:2100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37844aef-5de5-4289-9ab5-1a466d355fad")) {                    Plotly.newPlot(                        "37844aef-5de5-4289-9ab5-1a466d355fad",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041f\u0411","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u0421\u041f\u0411","\
# ...

# %%
df.division.value_counts(dropna=False).to_frame().reset_index()
# Out:
#   division  count
# 0      NaN     13
# 1       СМ      8
# 2       ХД      7
# 3       ТВ      3
# 4      МБС      2
# 5      УСТ      2
# 6       ПЛ      1

# %%
division_plot = plot_clusters(
    'Направления обращений', df, 'division', 36, 40, {None: 'Не выгружен'}
)
division_plot.show()
# Out:
# <div>                            <div id="bf5a8748-bbc8-4f87-bbf3-a3d2c3cef462" class="plotly-graph-div" style="height:900px; width:2100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf5a8748-bbc8-4f87-bbf3-a3d2c3cef462")) {                    Plotly.newPlot(                        "bf5a8748-bbc8-4f87-bbf3-a3d2c3cef462",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u0421\u041c","\u041d\u0435 \u0432\u044b
# ...

# %%
df.device.value_counts(dropna=False).to_frame().reset_index()
# Out:
#     device  count
# 0      NaN     13
# 1  Samsung     12
# 2   Xiaomi      7
# 3   Realme      2
# 4  Infinix      1
# 5   Huawei      1

# %%
device_plot = plot_clusters(
    'Устройства-источники обращений', df, 'device', 36, 40, {None: 'Не выгружен'}
)
device_plot.show()
# Out:
# <div>                            <div id="12dcf76b-fb17-4a1c-8b46-422439d53e0d" class="plotly-graph-div" style="height:900px; width:2100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12dcf76b-fb17-4a1c-8b46-422439d53e0d")) {                    Plotly.newPlot(                        "12dcf76b-fb17-4a1c-8b46-422439d53e0d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Samsung","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Xiaomi","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Samsung","Samsung","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0
# ...

# %%
df[df.cluster == 'Проблемы с загрузкой и отображением фото'].device.value_counts(dropna=False).to_frame().reset_index()
# Out:
#     device  count
# 0  Samsung      6
# 1      NaN      5
# 2   Xiaomi      2
# 3  Infinix      1

# %%
device_plot = plot_clusters(
    'Устройства-источники обращений по поводу фото', df[df.cluster == 'Проблемы с загрузкой и отображением фото'], 'device', 36, 40, {None: 'Не выгружен'}
)
device_plot.show()
# Out:
# <div>                            <div id="17223ceb-6440-40ba-96cc-61f1d5e5fece" class="plotly-graph-div" style="height:900px; width:2100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17223ceb-6440-40ba-96cc-61f1d5e5fece")) {                    Plotly.newPlot(                        "17223ceb-6440-40ba-96cc-61f1d5e5fece",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Samsung","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Xiaomi","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Xiaomi","Samsung","Samsung","Infinix","Samsung","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","Samsung","\u041d\
# ...
