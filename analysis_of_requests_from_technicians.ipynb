# %%
import json

import qa_extract
import pandas as pd
import plotly.io as pio

from text_conversion import clean_json, parse_data
from clusterization import llm_clusterization, plot_clusters

pd.set_option("display.max_colwidth", None)
pio.renderers.default = "notebook_connected"

SEED = 654321

# %%
res = qa_extract.main()

with open("data/qa.json", "r") as f:
    qa = json.load(f)

clean_qa = clean_json(qa)

# %%
clusters = llm_clusterization(clean_qa, "gpt-4-1106-preview", SEED)

with open('data/clusters.json', 'w',  encoding='utf-8') as f:
    json.dump(clusters, f, ensure_ascii=False, indent=4)
with open("data/clusters.json", "r") as f:
    clusters = json.load(f)

clusters
# Out:
# {'Проблемы с загрузкой и отображением фото': ['3',
#   '30',
#   '34',
#   '38',
#   '41',
#   '48',
#   '53',
#   '79',
#   '82',
#   '84',
#   '98',
#   '113',
#   '142',
#   '158'],
#  'Сбой в приложении и UI-оптимизация': ['7', '9', '68', '148'],
#  'Потребность в обновлении приложения': ['13', '129', '153'],
#  'Некорректная работа комментариев к заявкам': ['17', '65', '89', '93'],
#  'Технические вопросы про использование приложения': ['25'],
#  'Чрезмерный расход заряда батареи': ['27', '36'],
#  'Вопросы по переносу заявок и навигации в приложении': ['75'],
#  'Проблема с уведомлениями': ['59', '62', '133'],
#  'Сложности со связью и звонками': ['72', '116', '125']}

# %%
cluster_map = {id_: name for name, ids in clusters.items() for id_ in ids}

rows = []
for item in qa:
    for key, value in item.items():
        if key.startswith('Answer'):
            question_id = key.split(" ")[1]
            affilate, division = parse_data(value, 'affilate', 'division')
            cluster_name = cluster_map.get(question_id, "Нет ответа")
            rows.append(
                {
                    "id": question_id,
                    "affilate": affilate,
                    "division": division,
                    "cluster": cluster_name,
                }
            )

df = pd.DataFrame(rows)
df
# Out:
#      id affilate division                                              cluster
# 0     3     None     None             Проблемы с загрузкой и отображением фото
# 1     7      МСК       ХД                   Сбой в приложении и UI-оптимизация
# 2     9     None     None                   Сбой в приложении и UI-оптимизация
# 3    13     None     None                  Потребность в обновлении приложения
# 4    17      СПБ       СМ           Некорректная работа комментариев к заявкам
# 5    25     None     None     Технические вопросы про использование приложения
# 6    27      МСК       ХД                     Чрезмерный расход заряда батареи
# 7    30      СПБ       СМ             Проблемы с загрузкой и отображением фото
# 8    34     None     None             Проблемы с загрузкой и отображением фото
# 9    36     None     None                     Чрезмерный расход заряда батареи
# 10   38      СПБ       СМ             Проблемы с загрузкой и отображением фото
# 11   41     None     None             Проблемы с загрузкой и отображением фото
# 12   48      МСК       ХД             Проблемы с загрузкой и отображением фото
# 13   51      МСК      МБС                                           Нет ответа
# 14   53      МСК      УСТ             Проблемы с загрузкой и отображением фото
# 15   59      СПБ       ТВ                             Проблема с уведомлениями
# 16   62      МСК       ХД                             Проблема с уведомлениями
# 17   65      МСК       ХД           Некорректная работа комментариев к заявкам
# 18   68     None     None                   Сбой в приложении и UI-оптимизация
# 19   72     None     None                       Сложности со связью и звонками
# 20   75      МСК       СМ  Вопросы по переносу заявок и навигации в приложении
# 21   79      СПБ       ТВ             Проблемы с загрузкой и отображением фото
# 22   82      ЕКБ       СМ             Проблемы с загрузкой и отображением фото
# 23   84      МСК       ПЛ             Проблемы с загрузкой и отображением фото
# 24   89     None     None           Некорректная работа комментариев к заявкам
# 25   93      НСК       ХД           Некорректная работа комментариев к заявкам
# 26   98     None     None             Проблемы с загрузкой и отображением фото
# 27  113      МСК       СМ             Проблемы с загрузкой и отображением фото
# 28  116      ЕКБ      МБС                       Сложности со связью и звонками
# 29  125      ЕКБ       ХД                       Сложности со связью и звонками
# 30  129     None     None                  Потребность в обновлении приложения
# 31  133      МСК       ТВ                             Проблема с уведомлениями
# 32  142     None     None             Проблемы с загрузкой и отображением фото
# 33  148      МСК       СМ                   Сбой в приложении и UI-оптимизация
# 34  153      МСК       СМ                  Потребность в обновлении приложения
# 35  158      МСК      УСТ             Проблемы с загрузкой и отображением фото

# %%
df.to_csv("mrm_clusters.csv", index=False)
df = pd.read_csv("mrm_clusters.csv")

# %%
df.cluster.value_counts().to_frame().reset_index()
# Out:
#                                                cluster  count
# 0             Проблемы с загрузкой и отображением фото     14
# 1                   Сбой в приложении и UI-оптимизация      4
# 2           Некорректная работа комментариев к заявкам      4
# 3                  Потребность в обновлении приложения      3
# 4                             Проблема с уведомлениями      3
# 5                       Сложности со связью и звонками      3
# 6                     Чрезмерный расход заряда батареи      2
# 7     Технические вопросы про использование приложения      1
# 8                                           Нет ответа      1
# 9  Вопросы по переносу заявок и навигации в приложении      1

# %%
cluster_plot = plot_clusters("Типы обращений", df, "cluster", 36, 30)
cluster_plot.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="22a91cea-a27f-4e00-8258-b8d70a8b9d87" class="plotly-graph-div" style="height:900px; width:2200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22a91cea-a27f-4e00-8258-b8d70a8b9d87")) {                    Plotly.newPlot(                        "22a91cea-a27f-4e00-8258-b8d70a8b9d87",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"cluster=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u0421\u0431\u043e\u0439 \u0432 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0438 \u0438 UI-\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f","\u0421\u0431\u043e\u0439 \u0432 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u0438 \u0438 UI-\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f","\u041f\u043e\u0442\u0440\u0435\u0431\u043d\u043e\u0441\u0442\u044c \u0432 \u043e\u0431\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0438 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u044f","\u041d\u0435\u043a\u043e\u0440\u0440\u0435\u043a\u0442\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430 \u043a\u043e\u043c\u043c\u0435\u043d\u0442\u0430\u0440\u0438\u0435\u0432 \u043a \u0437\u0430\u044f\u0432\u043a\u0430\u043c","\u0422\u0435\u0445\u043d\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u0432\u043e\u043f\u0440\u043e\u0441\u044b \u043f\u0440\u043e \u0438\u0441\u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u043d\u0438\u0435 \u043f\u0440\u0438\u043b\u043e\u0436\u0435\u043d\u0438\u044f","\u0427\u0440\u0435\u0437\u043c\u0435\u0440\u043d\u044b\u0439 \u0440\u0430\u0441\u0445\u043e\u0434 \u0437\u0430\u0440\u044f\u0434\u0430 \u0431\u0430\u0442\u0430\u0440\u0435\u0438","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u0427\u0440\u0435\u0437\u043c\u0435\u0440\u043d\u044b\u0439 \u0440\u0430\u0441\u0445\u043e\u0434 \u0437\u0430\u0440\u044f\u0434\u0430 \u0431\u0430\u0442\u0430\u0440\u0435\u0438","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u041d\u0435\u0442 \u043e\u0442\u0432\u0435\u0442\u0430","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u044b \u0441 \u0437\u0430\u0433\u0440\u0443\u0437\u043a\u043e\u0439 \u0438 \u043e\u0442\u043e\u0431\u0440\u0430\u0436\u0435\u043d\u0438\u0435\u043c \u0444\u043e\u0442\u043e","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u0430 \u0441 \u0443\u0432\u0435\u0434\u043e\u043c\u043b\u0435\u043d\u0438\u044f\u043c\u0438","\u041f\u0440\u043e\u0431\u043b\u0435\u043c\u0430 \u0441 \u0443\u0432\u0435\u0434\u043e\u043c\u043b\u0435\u043d\u0438\u044f\u043c\u0438","\u041d\u0435\u043a\u043e\u0440\u0440\u0435\u043a\u0442\u043d\u0430\u044f \u ...

# %%
df.affilate.value_counts(dropna=False).to_frame().reset_index()
# Out:
#   affilate  count
# 0      МСК     14
# 1     None     13
# 2      СПБ      5
# 3      ЕКБ      3
# 4      НСК      1

# %%
affilate_plot = plot_clusters(
    "Филиалы обращений",
    df,
    "affilate",
    36,
    40,
    {None: "Не выгружен"}
)
affilate_plot.show()
# Out:
# <div>                            <div id="16d7faba-0666-48f8-80dd-f7959c35d41a" class="plotly-graph-div" style="height:900px; width:2200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16d7faba-0666-48f8-80dd-f7959c35d41a")) {                    Plotly.newPlot(                        "16d7faba-0666-48f8-80dd-f7959c35d41a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041f\u0411","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u0421\u041f\u0411","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041f\u0411","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u041c\u0421\u041a","\u041c\u0421\u041a","\u0421\u041f\u0411","\u041c\u0421\u041a","\u041c\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u0421\u041f\u0411","\u0415\u041a\u0411","\u041c\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u0415\u041a\u0411","\u0415\u041a\u0411","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041c\u0421\u041a","\u041c\u0421\u041a","\u041c\u0421\u041a"],"legendgroup":"","name":"","showlegend":true,"type":"pie","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555 ...

# %%
df.division.value_counts(dropna=False).to_frame().reset_index()
# Out:
#   division  count
# 0     None     13
# 1       СМ      8
# 2       ХД      7
# 3       ТВ      3
# 4      МБС      2
# 5      УСТ      2
# 6       ПЛ      1

# %%
division_plot = plot_clusters(
    "Направления обращений", df, "division", 36, 40, {None: "Не выгружен"}
)
division_plot.show()
# Out:
# <div>                            <div id="c96ccb1c-8cf0-44c4-972b-edb0af208031" class="plotly-graph-div" style="height:900px; width:2200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c96ccb1c-8cf0-44c4-972b-edb0af208031")) {                    Plotly.newPlot(                        "c96ccb1c-8cf0-44c4-972b-edb0af208031",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u0421\u041c","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u041c\u0411\u0421","\u0423\u0421\u0422","\u0422\u0412","\u0425\u0414","\u0425\u0414","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u0422\u0412","\u0421\u041c","\u041f\u041b","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0425\u0414","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u041c\u0411\u0421","\u0425\u0414","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0422\u0412","\u041d\u0435 \u0432\u044b\u0433\u0440\u0443\u0436\u0435\u043d","\u0421\u041c","\u0421\u041c","\u0423\u0421\u0422"],"legendgroup":"","name":"","showlegend":true,"type":"pie","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...
